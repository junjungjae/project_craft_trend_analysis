# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

# %%
df = pd.read_csv('./csv/클래스101_카테고리포함.csv')
df.head()
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.sort_values(by='댓글날짜', ascending=False)[:50]
# 제일 오래 된 댓글 ; 꽁냥 꽁냥, 고양이는 진리 수 놓는 발바닥과 함께하는 고양이 자수 18.11.27
# 가장 최근 댓글 21.5.9
# Out:
#                                                      강의명   댓글수  \
# 17383             [??2시간 뒤 종료] 모루로 만드는 내 손 안의 귀염둥이, 모루인형    45
# 15877  [??2시간 뒤 종료] 인스타그램으로 세상에 나의 가치를 알려보자. 인스타그램 퍼스...  1205
# 25          [??오늘 종료] 행복한 취미로 월 200만원 버는 방법, 수공예 투잡 도전하기   194
# 2135            [??오늘 종료] 처음하는 라탄공예, 내 손으로 만드는 10가지 라탄소품   334
# 2518    [??오늘 종료] 분위기를 반전시키는 빛, 더베러라이프의 네온공예. 민간자격증 취득까지    45
# 15295  [??2시간 뒤 종료] 손바느질로 짓는 전통 사극 한 편, 인형 궁중한복과 남자한복...   154
# 6332        [??오늘 종료] 마크라메로 만드는 6가지 가방과 소품, 컬러풀한 하루를 엮어요   238
# 17595             [??2시간 뒤 종료] 색다른컬러연구소 유잰에게 배우는 배색 노하우!   327
# 17596             [??2시간 뒤 종료] 색다른컬러연구소 유잰에게 배우는 배색 노하우!   327
# 17597             [??2시간 뒤 종료] 색다른컬러연구소 유잰에게 배우는 배색 노하우!   327
# 17370             [??2시간 뒤 종료] 모루로 만드는 내 손 안의 귀염둥이, 모루인형    45
# 1918         [??오늘 종료] 일상을 빛나게, 섬세한 금속 공예로 만나는 핸드메이드 주얼리   685
# 13921     [??2시간 뒤 종료] 원석과 비즈로 '깨알같이' 엮어내는 14가지 액세서리와 소품    24
# 7265               [??오늘 종료] 보송보송 실로 그려내는 그림, 도톰자수의 펀치니들    20
# 4867           [??오늘 종료] 만질수록 아름다워지는 전통매듭, 10가지 매듭법으로 엮기   110
# 13329        [??2시간 뒤 종료] 프랑스 출신 조향사와 함께 떠나는, 새로운 향기의 세계   134
# 17414  [??2시간 뒤 종료] 잊히지 않는 선물, 재료와 기법부터 전문가에게 배우는 16가...    25
# 17415  [??2시간 뒤 종료] 잊히지 않는 선물, 재료와 기법부터 전문가에게 배우는 16가...    25
# 11046    [??3시간 뒤 종료] 취미로 시작해서 온라인 창업까지! 시들지 않는 꽃, 실크플라워   163
# 8042           [??오늘 종료] 종이로 전하는 메세지, 토퍼 만들기부터 창업과 판매까지!   199
# 12222         [??2시간 뒤 종료] 자연의 빛 그대로, 순간을 담아내는 나만의 레진 아트    20
# 8987                  [??오늘 종료] 손그림으로 콕콕! 쉽고 재밌는 펀치니들 자수    51
# 12232         [??2시간 뒤 종료] 자연의 빛 그대로, 순간을 담아내는 나만의 레진 아트    20
# 14084  [??2시간 뒤 종료] 공간에 생생한 감각을 더해요, 펀치니들을 이용한 터프팅 소품...   137
# 13927     [??2시간 뒤 종료] 원석과 비즈로 '깨알같이' 엮어내는 14가지 액세서리와 소품    24
# 8102           [??오늘 종료] 종이로 전하는 메세지, 토퍼 만들기부터 창업과 판매까지!   199
# 7856           [??오늘 종료] 일상의 모든 것을 재료로 '나만의 북바인딩 노트' 만들기   104
# 7857           [??오늘 종료] 일상의 모든 것을 재료로 '나만의 북바인딩 노트' 만들기   104
# 3618            [??오늘 종료] 한땀 한땀, 손안에 쏙 들어오는 인형 가죽 신발과 가방   433
# 3617            [??오늘 종료] 한땀 한땀, 손안에 쏙 들어오는 인형 가죽 신발과 가방   433
# 3616            [??오늘 종료] 한땀 한땀, 손안에 쏙 들어오는 인형 가죽 신발과 가방   433
# 8103           [??오늘 종료] 종이로 전하는 메세지, 토퍼 만들기부터 창업과 판매까지!   199
# 12453         [??2시간 뒤 종료] 귀여워 너무 귀여워! 로빈을 따라 만드는 뜨개 인형들   445
# 7360            [??오늘 종료] 햇살처럼 따듯한 스테인드글라스, 나의 오늘을 밝혀줘요.   472
# 14083  [??2시간 뒤 종료] 공간에 생생한 감각을 더해요, 펀치니들을 이용한 터프팅 소품...   137
# 8860         [??오늘 종료] 소중한 마음을 담아, 초보도 쉽게 만드는 달빈의 재봉틀 수업   118
# 14082  [??2시간 뒤 종료] 공간에 생생한 감각을 더해요, 펀치니들을 이용한 터프팅 소품...   137
# 14081  [??2시간 뒤 종료] 공간에 생생한 감각을 더해요, 펀치니들을 이용한 터프팅 소품...   137
# 8235             [??오늘 종료] 시간을 들여 천천히, 라탄으로 엮는 7가지 감성 소품    31
# 12324         [??2시간 뒤 종료] 귀여워 너무 귀여워! 로빈을 따라 만드는 뜨개 인형들   445
# 17138               [??2시간 뒤 종료] 느림의 미학, 사진작가 신혜림의 필름 사진   502
# 65          [??오늘 종료] 행복한 취미로 월 200만원 버는 방법, 수공예 투잡 도전하기   194
# 66          [??오늘 종료] 행복한 취미로 월 200만원 버는 방법, 수공예 투잡 도전하기   194
# 67          [??오늘 종료] 행복한 취미로 월 200만원 버는 방법, 수공예 투잡 도전하기   194
# 68          [??오늘 종료] 행복한 취미로 월 200만원 버는 방법, 수공예 투잡 도전하기   194
# 17206  [??2시간 뒤 종료] [S4E]케이크토퍼 & 시트지커팅 _10년차 전문강사가 알려...   220
# 11662        [??2시간 뒤 종료] 차분히 즐기는 멘티의 프랑스자수, 6가지 생활소품으로!   335
# 3619            [??오늘 종료] 한땀 한땀, 손안에 쏙 들어오는 인형 가죽 신발과 가방   433
# 7166                 [??오늘 종료] 즐거움을 엮는 실 이야기, 유니크한 핸드위빙    171
# 3381        [??오늘 종료] 더 쉽게, 더 꼼꼼하게 완성하는 인형 신발과 가죽 가방 클래스    59
#
#                                                     댓글내용         댓글날짜     년  \
# 17383                                               좋아요!  2021. 5. 9.  2021
# 15877                                               좋아요!  2021. 5. 9.  2021
# 25                               기초적인거부터 차근차근 알려주셔서 좋았어요  2021. 5. 9.  2021
# 2135                                 반복해서 수강할 수 있어 만족합니다  2021. 5. 9.  2021
# 2518                                                   .  2021. 5. 9.  2021
# 15295                                               좋아요!  2021. 5. 9.  2021
# 6332                                                좋아요!  2021. 5. 9.  2021
# 17595                                               좋아요!  2021. 5. 9.  2021
# 17596                                               좋아요!  2021. 5. 9.  2021
# 17597                                               좋아요!  2021. 5. 9.  2021
# 17370                                        귀엽고 재미있어오ㅡㅇ  2021. 5. 9.  2021
# 1918                                                좋아요!  2021. 5. 9.  2021
# 13921  도안과 패턴을 그림으로 알아보기 쉽게 정리해 주셔서 영상과 함께 천천히 따라하기 좋았어요  2021. 5. 9.  2021
# 7265                                                좋아요!  2021. 5. 9.  2021
# 4867                                                좋아요!  2021. 5. 9.  2021
# 13329                                               좋아요!  2021. 5. 9.  2021
# 17414                                               좋아요!  2021. 5. 9.  2021
# 17415                                               좋아요!  2021. 5. 9.  2021
# 11046                                             꼼꼼한 설명  2021. 5. 9.  2021
# 8042                               쉬운 설명으로 수업진행이 순조로웠습니다  2021. 5. 9.  2021
# 12222                  만들때 초보자들이 실수 할 수 있는 부분을 짚어주셔서 좋아요  2021. 5. 9.  2021
# 8987                                                좋아요!  2021. 5. 9.  2021
# 12232                                               좋아요!  2021. 5. 9.  2021
# 14084                                               좋아요!  2021. 5. 9.  2021
# 13927                                               좋아요!  2021. 5. 9.  2021
# 8102                                                좋아요!  2021. 5. 9.  2021
# 7856                                                좋아요!  2021. 5. 9.  2021
# 7857                                                좋아요!  2021. 5. 9.  2021
# 3618                                                좋아요!  2021. 5. 9.  2021
# 3617                                                좋아요!  2021. 5. 9.  2021
# 3616                                                좋아요!  2021. 5. 9.  2021
# 8103                                                좋아요!  2021. 5. 9.  2021
# 12453                                               좋아요!  2021. 5. 9.  2021
# 7360                                                좋아요!  2021. 5. 9.  2021
# 14083                                               좋아요!  2021. 5. 9.  2021
# 8860                                                좋아요!  2021. 5. 9.  2021
# 14082                                               좋아요!  2021. 5. 9.  2021
# 14081                                               좋아요!  2021. 5. 9.  2021
# 8235                                                좋아요!  2021. 5. 8.  2021
# 12324  설명이 친절하고 자세해서 좋아요 다만 나중에 기간이 끝난후를 대비해 수업노트를 다운...  2021. 5. 8.  2021
# 17138                                               좋아요!  2021. 5. 8.  2021
# 65                                                  좋아요!  2021. 5. 8.  2021
# 66                                                  좋아요!  2021. 5. 8.  2021
# 67                                                  좋아요!  2021. 5. 8.  2021
# 68                                                  좋아요!  2021. 5. 8.  2021
# 17206                                               좋아요!  2021. 5. 8.  2021
# 11662                                               좋아요!  2021. 5. 8.  2021
# 3619                                                좋아요!  2021. 5. 8.  2021
# 7166                                                좋아요!  2021. 5. 8.  2021
# 3381                                             친절한 설명ㆍ  2021. 5. 8.  2021
#
#        월  좋아요수      카테고리
# 17383  5   902    바느질/재봉
# 15877  5  4961        기타
# 25     5  1925        금속
# 2135   5  2856        라탄
# 2518   5   758        기타
# 15295  5  1506    바느질/재봉
# 6332   5  1821    바느질/재봉
# 17595  5  4111        기타
# 17596  5  4111        기타
# 17597  5  4111        기타
# 17370  5   902    바느질/재봉
# 1918   5  5264        금속
# 13921  5   615        금속
# 7265   5   562    바느질/재봉
# 4867   5  1836    바느질/재봉
# 13329  5  1962     캔들/방향
# 17414  5   709  페이퍼아트/포장
# 17415  5   709  페이퍼아트/포장
# 11046  5  1636   플라워/가드닝
# 8042   5  1764  페이퍼아트/포장
# 12222  5  1157        레진
# 8987   5   932    바느질/재봉
# 12232  5  1157        레진
# 14084  5  2015    바느질/재봉
# 13927  5   615        금속
# 8102   5  1764  페이퍼아트/포장
# 7856   5  1058    바느질/재봉
# 7857   5  1058    바느질/재봉
# 3618   5  1419        가죽
# 3617   5  1419        가죽
# 3616   5  1419        가죽
# 8103   5  1764  페이퍼아트/포장
# 12453  5  5951    바느질/재봉
# 7360   5  7947        유리
# 14083  5  2015    바느질/재봉
# 8860   5  2153    바느질/재봉
# 14082  5  2015    바느질/재봉
# 14081  5  2015    바느질/재봉
# 8235   5  1246        라탄
# 12324  5  5951    바느질/재봉
# 17138  5  1826        기타
# 65     5  1925        금속
# 66     5  1925        금속
# 67     5  1925        금속
# 68     5  1925        금속
# 17206  5  1527    바느질/재봉
# 11662  5  2710    바느질/재봉
# 3619   5  1419        가죽
# 7166   5  1992    바느질/재봉
# 3381   5   767        가죽

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17857 entries, 0 to 17856
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강의명     17857 non-null  object
#  1   댓글수     17857 non-null  object
#  2   댓글내용    17854 non-null  object
#  3   댓글날짜    17651 non-null  object
#  4   년       17857 non-null  object
#  5   월       17857 non-null  object
#  6   좋아요수    17857 non-null  int64
#  7   카테고리    17857 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.1+ MB

# %%
df['강의명'].value_counts()
# Out:
# [??2시간 뒤 종료] 인스타그램으로 세상에 나의 가치를 알려보자. 인스타그램 퍼스널 브랜딩         1205
# [??오늘 종료] 퇴근 후 만나는 나의 가죽 공방, 가죽공예 기초부터 완성까지!                 925
# [??오늘 종료] 두 손과 실로 그려가는 마크라메 매듭 악세사리                          596
# [??오늘 종료] 벌집에서 추출한 100% 천연왁스로 ‘밀랍 꽃’ 만들기                     456
# [??2시간 뒤 종료] 귀여워 너무 귀여워! 로빈을 따라 만드는 뜨개 인형들                   445
#                                                             ...
# DIY 베지터블 가죽지갑 & 키링 키트                                          1
# [??오늘 종료] 쉬어가는 나만의 공간, 감성충만 디저트 캔들 만들기                         1
# [??오늘 종료] 추상적이고 아름다운, 흐름의 미학 '알코올잉크아트'                         1
# [??2시간 뒤 종료] [꿀조합 할인??] 나만의 도자기를 직접 만들고 채색까지, 집 안의 도예 공방       1
# 프리미엄 상품! 최고급 디지털의 SINGER 7640 미싱기                              1
# Name: 강의명, Length: 307, dtype: int64

# %%
df.isnull().sum()
# Out:
# category      0
# title         0
# datetime    246
# review      254
# star        246
# dtype: int64

# %%
null = df[df['댓글내용'] =='none'].index
df.drop(null,inplace=True) # 댓글 없는 것들 제거

# %%
df['댓글내용'].value_counts()
# Out:
# 좋아요!                                                      10970
# 아쉬웠어요...                                                    242
# 좋아요                                                          49
# 재밌어요                                                         33
# .                                                            25
#                                                           ...
# 하나하나 따라하기 쉽게 설명을해주십니다                                         1
# 다양한 기법으로 작품을 표현할 수 있어 좋았어요                                    1
# 가방을 만들어볼수 있어 좋아요.                                             1
# 조금만 연습하면 실패없는 뜨기가 가능해요. 자유롭게 응용할수있는 유용한 뜨기법을 배울 수 있습니다        1
# 피드백도 좋고 모르는 부분을 많이 알게 됐어요~                                    1
# Name: 댓글내용, Length: 5995, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17651 entries, 0 to 17811
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강의명     17651 non-null  object
#  1   댓글수     17651 non-null  object
#  2   댓글내용    17648 non-null  object
#  3   댓글날짜    17651 non-null  object
#  4   년       17651 non-null  object
#  5   월       17651 non-null  object
#  6   좋아요수    17651 non-null  int64
#  7   카테고리    17651 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.2+ MB

# %%
df['강의명'].value_counts()
# Out:
# [??2시간 뒤 종료] 인스타그램으로 세상에 나의 가치를 알려보자. 인스타그램 퍼스널 브랜딩         1205
# [??오늘 종료] 퇴근 후 만나는 나의 가죽 공방, 가죽공예 기초부터 완성까지!                 925
# [??오늘 종료] 두 손과 실로 그려가는 마크라메 매듭 악세사리                          596
# [??오늘 종료] 벌집에서 추출한 100% 천연왁스로 ‘밀랍 꽃’ 만들기                     456
# [??2시간 뒤 종료] 귀여워 너무 귀여워! 로빈을 따라 만드는 뜨개 인형들                   445
#                                                             ...
# DIY 베지터블 가죽지갑 & 키링 키트                                          1
# [??오늘 종료] 쉬어가는 나만의 공간, 감성충만 디저트 캔들 만들기                         1
# [??오늘 종료] 추상적이고 아름다운, 흐름의 미학 '알코올잉크아트'                         1
# [??2시간 뒤 종료] [꿀조합 할인??] 나만의 도자기를 직접 만들고 채색까지, 집 안의 도예 공방       1
# 프리미엄 상품! 최고급 디지털의 SINGER 7640 미싱기                              1
# Name: 강의명, Length: 307, dtype: int64

# %%
df.category.value_counts()
# Out:
# 캔들/발향      175
# 도자기        172
# 금속/악세사리    143
# 가죽          76
# 레진          71
# 바느질/재봉      69
# 유리          64
# 기타          63
# 우드/라탄       56
# Name: category, dtype: int64

# %%
review_length = df['댓글내용'].astype(str).apply(len)
review_length.head()
# Out:
# 0     53
# 1     50
# 2     43
# 3     92
# 4    235
# Name: 댓글내용, dtype: int64

# %%
review_length.value_counts()
# Out:
# 4      11082
# 8        326
# 20       180
# 17       156
# 15       148
#        ...
# 194        1
# 169        1
# 146        1
# 180        1
# 591        1
# Name: 댓글내용, Length: 208, dtype: int64

# %%
# 그래프에 대한 이미지 사이즈 선언
plt.figure(figsize=(12, 5))
plt.hist(review_length, bins=200, alpha=0.5, color= 'r', label='word')
plt.yscale('log', nonposy='clip') 

# 그래프 x 축 라벨
plt.xlabel('Length of review')
# 그래프 y 축 라벨
plt.ylabel('Number of review') # comment가 없는게 제일 많음
# Out:
# Text(0, 0.5, 'Number of review')

# %%
print('리뷰 길이 최대 값: {}'.format(np.max(review_length)))
print('리뷰 길이 최소 값: {}'.format(np.min(review_length)))
print('리뷰 길이 평균 값: {:.2f}'.format(np.mean(review_length)))
print('리뷰 길이 표준편차: {:.2f}'.format(np.std(review_length)))
print('리뷰 길이 중간 값: {}'.format(np.median(review_length)))
# 사분위의 대한 경우는 0~100 스케일로 되어있음
print('리뷰 길이 제 1 사분위: {}'.format(np.percentile(review_length, 25)))
print('리뷰 길이 제 3 사분위: {}'.format(np.percentile(review_length, 75)))
# Out:
# 리뷰 길이 최대 값: 591
# 리뷰 길이 최소 값: 1
# 리뷰 길이 평균 값: 16.07
# 리뷰 길이 표준편차: 26.58
# 리뷰 길이 중간 값: 4.0
# 리뷰 길이 제 1 사분위: 4.0
# 리뷰 길이 제 3 사분위: 19.0

# %%
plt.figure(figsize=(12, 5))
# 박스플롯 생성
# 첫번째 파라메터: 여러 분포에 대한 데이터 리스트를 입력
# labels: 입력한 데이터에 대한 라벨
# showmeans: 평균값을 마크함

plt.boxplot(review_length,
             labels=['counts'],
             showmeans=True) # 길이가 긴 데이터가 꽤 있음
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x212fdb99c10>,
#   <matplotlib.lines.Line2D at 0x212fdb99f70>],
#  'caps': [<matplotlib.lines.Line2D at 0x212fd75f310>,
#   <matplotlib.lines.Line2D at 0x212fd75f670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x212fdb998b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x212fd75f970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x212fd75ffd0>],
#  'means': [<matplotlib.lines.Line2D at 0x212fd75fc70>]}

# %%
train_review = [review for review in df['댓글내용'] if type(review) is str] # str 아닌 것 제거

# %%
wordcloud = WordCloud(font_path ='NanumGothic.ttf').generate(' '.join(train_review))
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation = 'bilinear') # 글자의 배열 형태를 bilinear로 지정, 2개의 선??
plt.axis('off') # x, y 축 나오지 않게하기
plt.show()

# %%
word_counts = df['댓글내용'].astype(str).apply(lambda x:len(x.split(' ')))

# %%
plt.figure(figsize=(15, 10))
plt.hist(word_counts, bins=50, facecolor='r',label='train')
plt.title('Log-Histogram of word count in review', fontsize=15)
plt.yscale('log', nonposy='clip')
plt.legend()
plt.xlabel('Number of words', fontsize=15)
plt.ylabel('Number of reviews', fontsize=15)
# Out:
# Text(0, 0.5, 'Number of reviews')

# %%
print('리뷰 단어 개수 최대 값: {}'.format(np.max(word_counts)))
print('리뷰 단어 개수 최소 값: {}'.format(np.min(word_counts)))
print('리뷰 단어 개수 평균 값: {:.2f}'.format(np.mean(word_counts)))
print('리뷰 단어 개수 표준편차: {:.2f}'.format(np.std(word_counts)))
print('리뷰 단어 개수 중간 값: {}'.format(np.median(word_counts)))
# 사분위의 대한 경우는 0~100 스케일로 되어있음
print('리뷰 단어 개수 제 1 사분위: {}'.format(np.percentile(word_counts, 25)))
print('리뷰 단어 개수 제 3 사분위: {}'.format(np.percentile(word_counts, 75)))# 최대 단어 개수를 6, 7개
# Out:
# 리뷰 단어 개수 최대 값: 131
# 리뷰 단어 개수 최소 값: 1
# 리뷰 단어 개수 평균 값: 3.64
# 리뷰 단어 개수 표준편차: 6.03
# 리뷰 단어 개수 중간 값: 1.0
# 리뷰 단어 개수 제 1 사분위: 1.0
# 리뷰 단어 개수 제 3 사분위: 4.0
