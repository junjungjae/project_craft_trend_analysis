# %% [markdown]
# ## 긍정부분 감정분석

# %%
import numpy as np
import pandas as pd


def neg_counter(data):
    negative_n = 0
    neg_front_search = ['보이지', '아깝다', '충분하다않다', '더자세하다', '더좋다', '아쉽다',
                        '쓸데없다', '느리다', '빠르다', '면 좋다', '좋다것같다', '안되다',
                        '헤메다', ' 좋다듯하다', '부족하다', '더들어가다', '어렵다', '비싸', '빠르다것같다', '자주나가다', '그만',
                        '너무늦다', '부족하다', '부분', '당황', '안타깝다']

    neg_back_search = ['다만', '없다', '그런데', '충분하다않다', '조금 더', '근데', '쓸데없다', '솔직', '너무짧다']

    neg_binary_search = ['실망', '부족', '버거운', '것같다', '좋다것같다', '단점', '너무짧다', '어렵다',
                         '때문에', '보완', '섬세', '너무많다', '무리', '않다', '기다']

    # 실망 댓글에서 분류하기 위한 3가지 카테고리 => 영상 품질 실망, 컨텐츠 내용 실망, 재료 관련 실망 카테고리
    neg_video_accord = ['버퍼링', '화질', '속도', '빠르다', '짧다', '보이지않다', '놓치다', '오류', '어둡다', '어두워지다',
                        '안들리다', '보이지', '안보이', '영상', '진도', '뚝뚝', '버퍼링', '스킵', '모양', '안들리다', '세밀',
                        '사이트', '과정', '하단', '확대', '보기', '감기', '초점', '안보이', '화질', '목소리', '평가',
                        '어두워지다', '클로즈업', '안보', '가까이', '화면', '모션', '자막', '오류', '각도']

    neg_content_accord = ['힘들다', '어렵다', '구체적', '헷갈', '반복되다', '환기', '진행', '해소가', '뒤죽박죽',
                          '안나오다', '각인', '장식', '단어', '돈', '작품', '답', '답장', '설명', '방법', '듣기', '교재', '이해', '비용', '힘들다',
                          '어렵다', '깊이', '용이', '초보자', '피드백', '수업', '빠르다', '속도', '시간', '내용', '만들기', '답변', '정보', '진행',
                          '기법', '너무짧다', '강의', '반복되다', '예시', '처음', '앞']

    neg_material_accord = ['촌스럽다', '얇다', '상품', '안오다', '구슬', '준비물', '분량',
                           '패키지', '안오다', '제품', '구성', '주문', '재료', '프린터']

    neg_weight_word = ['다만', '그런데', '충분하다않다', '조금 더', '근데', '쓸데없다', '어렵다', '안타깝다', '좋다것같다',
                       '아쉽다', '더필요하다', '조금불편하다']

    neg_word_list_zip = [neg_front_search, neg_back_search, neg_binary_search,
                         neg_video_accord, neg_content_accord, neg_material_accord]

    for neg_word_list in neg_word_list_zip:
        for neg_word in neg_word_list:
            if neg_word in data:
                if neg_word in neg_weight_word:
                    negative_n += 6
                else:
                    negative_n += 1

    return negative_n


def pos_counter(data):
    positive_n = 0
    pos_front_search = ['빠르다', '감사', '알차다', '만족도', '성취감', '따르다', '구체적으로', '쉬다', '아주',
                        '자세하다', '알게', '좋다', '배우다', '꼼꼼하다', '쉽다', '피드백을', '가르치다', '따르다',
                        '뿌듯', '좋다']

    pos_back_search = ['빠르다', '감사', '알차다', '만족도', '성취감', '따르다', '구체적으로', '쉬다', '아주',
                       '자세하다', '알게', '좋다', '배우다', '꼼꼼하다', '쉽다', '피드백을', '가르치다', '따르다', '최고']

    # 긍정 댓글에서 분류하기 위한 2가지 카테고리 => 영상 설명, 결과물 만족 2가지 카테고리

    pos_content_accord = ['댓글', '답변', '친절', '정보', '팁', '성취', '설명', '피드백', '꼼꼼', '차분', '자세히', '차근차근',
                          '디테일', '기법', '상세', '강의', '이해', '자세', '쉽다', '다양', '실용', '알차다', '구체',
                          '노하우', '알차다']

    pos_product_accord = ['결과물', '디자인', '스타일', '퀄리티', '작품']

    pos_weight_word = ['최고', '너무 좋다', '뿌듯', '꼼꼼']

    pos_word_list_zip = [pos_front_search, pos_back_search, pos_content_accord, pos_product_accord]
    for pos_word_list in pos_word_list_zip:
        for pos_word in pos_word_list:
            if pos_word in data:
                if pos_word in pos_weight_word:
                    positive_n += 5
                else:
                    positive_n += 1

    return positive_n


def return_sentiment(data, weight_score):
    pos_score = pos_counter(data)
    neg_score = neg_counter(data)
    try:
        sentiment_percent = np.round((pos_score / (neg_score + pos_score)) * 100, 2)
    except:
        return 0, 0, 0, 'not enough data'

    if sentiment_percent > weight_score:
        return pos_score, neg_score, sentiment_percent, 'good'
    else:
        return pos_score, neg_score, sentiment_percent, 'sorry'


reviewList = pd.read_excel('./dataset/stemming_good_review(row_2774).xlsx', engine='openpyxl')
reviewList.drop(reviewList.loc[reviewList.review.isna()].index, axis=0, inplace=True)
reviewList.reset_index(inplace=True)
reviewList.drop('index', axis=1, inplace=True)

data_n = 0
correct_n = 0
fail_n = 0
not_correct_n = 0


print('<제대로 분석이 된 댓글들>\n')
for i in range(len(reviewList)):
    review = reviewList.iloc[i, 1]
    pos_score, neg_score, sent_per, sentiment = return_sentiment(review, 48)
    data_n += 1
    if sentiment == 'good':
        correct_n += 1


    elif sentiment == 'not enough data':
        not_correct_n += 1
        continue
    else:
        fail_n += 1
        print(review, i)

print('\n----------------------------긍정에 대한 감정분석 결과-------------------------------------')
print('전체 데이터 수: {}\n정확히 분류된 댓글: {}\n잘못 분류된 댓글: {}\n분류 정확도: {}%'.format(data_n, correct_n, fail_n, np.round(
    100 * correct_n / (correct_n + fail_n))))

# pos_score, neg_score, sent_per, sentiment =\
#     return_sentiment('작가님의 강의는 꼼꼼하다차다 좋다다른 클래스와 다르다준비물을 구매하다 않다 똑같이만들기는 쉬다 않다 . 사이즈도 안나오다 있다, 패턴만 따로구매도 안되다 하니 좀아쉽다. ㅠㅠ', 49)
# print(pos_score, neg_score, sent_per, sentiment)
# Out:
# <제대로 분석이 된 댓글들>
#
# 혼자 방 구석 서치만으로 자세하다알다 어렵다부분들까지 알다 좋다 17
# 차분하다알다 쉬다 천천히 설명하다 주시니까 만들다 과정이 어렵다않다  23
# 신기하다재다 내용이 많다 43
# 기본적인 것부터 알다 때문에 기초가 탄탄하다잡히다 아무 것도 모르다 기 본명칭부터 배우니까 다른 것들이 눈에 들어오다 시작하고 기존에 제가 사용하다 악세사리를 더 유심히 보다 되다 아직 궁금하다 많다배우다 싶다 많다프랑꼬를 통해 더 알아 갈다 생각이다저같이 아무 것도 모르다 분들취미로 여럽지 않다 배우다 싶다 분들이나 창업을 생각하다 분들도 도움이 되다 것같다고민하다 말다 주얼리 테라 피하다  49
# 제게는 많다의미를 가지게 되다 클래스이다 같다다른것은 차다 일단 집중과 다른 잡념들도 없애다 만들다 시간 내내즐겁다 51
# 다양하다기법을 이용한 악세사리 만들기에 이다 어렵다동선 말이까지 배우다 있다 좋다 52
# 손에 익숙하다않다 도구를 잡다 방법 등을 알다 만들다 성취 감이 생기다  54
# 여러가지 기법을 알다 있다세밀한 수업이다  61
# 악세사리의 품격을 업그레이드시키다 있다수업이다 62
# 너무 재미있다ㅎㅎ마지막 수업까지 빨리 듣다 싶다 ㅎ 63
# 부분 부분어렵다작업도 있다하작품이 하나 하나 완성되어다 때에 성취 감과 뿌듯하다너무 좋다 68
# 같다재료들로 여러가지 느낌의 주얼리를 만들다 수있다만들다 때마다 놀랍다한가지만 배우다 여러가지를 응용하다 수있다수업도 너무 재밌다 69
# 어렵다막히다 부분에 대해서 질문하다 늘알다 쉬다 설명해주다 개운하다마음이 듭니다 그리고색상을 알다 재미가 있다 78
# 색이 아직도 명확하다인식되다 않다 갈수록 공부하다 하다 더많아지다 느낌이다 79
# 역시 선생님 강의는 명쾌하다자다 들다 지루하다않다 여러번 반복하다 조색 마스터하다  82
# 차분하다분위기가 클래스 특성과 일단너무 잘맞다필기로 하다 이론 수업이 아니다직접 스티커로 붙이다 보다 체험해보다 진행하다 수업이라 지루하다않다  85
# 섞다 쓸다 때 먼저 색이 보이지않다 하다 앞에 칼라를 비교하다 섞다 방법을 알게 되어다  89
# 설명도 디테일하고 문의사항 답변도 빠르다피드백해주다 깔다 현강에서 듣다 수업같다무엇보다 워크다 북과 지정색 표를 이용한 수업 자료가 퀄리티가 너무 높다완성하고 소장하다 두다 든든하다 같다 90
# 색에 대한 탐구 심이 있다사람에게 만족스럽다수업이다계속 공부하고 싶다  97
# 색에 대해 좀 더심다 이해를 하다 수있다되다 것같다task가다 너무 쉬다 어렵다않다 적당하다성취감다 있다 100
# 색에 대해자다 안다 생각하다 하다 보다 자다 안되다부분도 하나씩있다그래도 따라가다 너무 어렵다않다 사 기저하되다 않다 재밌다매일 저녁 힐링이에요  101
# 유재다 선생님의 차분하다진행 해주시는 강의에 초등학생이 들다 이해가 되게 너무 설명을 잘해주다 수업 진행 상태를 댓글로 확인하다 때만큼 콩닥거리다 칭찬과 격려를 많이 해주다  105
# 유채색과 무채색을 비교하다 설명한 부분이 명도의 개념을 보다 자다 이해하다 수있다해주다  112
# 힐링과 재미와 역시 난 미술은 아니다구나라는 자아 성찰과 여하튼재밌다아직 까지는 따라가다 무리가 없다 117
# 필요하다내용을 정확하다세심하다 집다 담백하다설명이 피로 감없이 힐링하다 수업이다 118
# 정답이 뒷부분에 있다모르다 직접해보다 정답 확인 후 강의를 마저들다 더 적극적으로 수업을 듣다 되어다  127
# 단계 별로 차근차근친절하다설명해주다 주의 사항도 똑같다내용 이지마 누매 수업마다 강조해주다 잊어버리다 않다 해주다  135
# 익숙하다색들이지만 색을 직접섞다 해보다 은근신박한 부분들이 있다무척흥미롭다 139
# 쉬다 생가 괬늘다 생각보다 어렵다연습을 통해 감각을 익히다 중요하다 140
# 느낌에만 의존하다 막연하다생각되다 색에 대해 체계있다이해가 생기다 가다 곳을 긁다 수업 142
# 너무 유용하다 좋다실생활 활용 사례도 같이 알다 좋다것같다 144
# 핸드폰으로 활용하게 해주다 예시를 너무 잘들어주다 같다아좀어렵다하다 바로어리다 하다 바로 팁을 알다 깜짝깜짝 놀라다 있다 150
# 차근차근 설명해주다 어렵다느끼다 수있다컨텐츠인데 도 이해가 자다 되다 좋다 151
# 일반적으로 알다 없다부분들을 이론으로 명확하다설명해주다 있다그래도 헷갈리다요ㅎㅎ 155
# 일상생활에 어떻다쓰이다 있다예시를 들어주다 더 기억에 남고 더빠르다이해를 하다 수있다 157
# 조색과 스티커 붙이기르다 지루하다않다 반복하다 번갈아가다 학습하다 더 정리가 되다 이해가 쏙쏙돼다  158
# 내용은 많다않다 느끼다 한데새롭다알게 되다 내용이 있다 재밌다 162
# 하나 하나 차근차근 진행하다 이해가 어렵다내용이라도 강의를 따라가다 수있다해주다 좋다 169
# 설명이 어렵다않다 콕콕 짚다 해주다 어렵다않다 배우다 수있다 187
# 태교 목적과 시작하다 취미가 되다 같다ㅎㅎ시간가다 모르다 ㅎㅎ 200
# 한번으로 익히다 것이 아니다반복하다 볼 수있다 좋다또 수업 설명이 어렵다않다 쉬다 알다 좋다 201
# 아주만족하다살짝어렵다부분도 있다개인적으로 11로 물어서 답변도 잘해주다  203
# 물감섞다 재미있다 원하다되다 않다 웃기고 색깔이 오묘하다정말 취향 저격이네 요 207
# 실습하다 전 눈으로 익히다 강의만 먼저듣다 있다앞으로가 더 기대돼다  209
# 별로라기보다는 아쉽다부분이 많다2액형레진을 혼합하는 법등앞 강의에 겹치다 부분이 빠지다 좋다생각하다 마무리가 계속 글리터 뿌리 기로되 늘다 아쉽다계속 바다 표현만 한게좀지루하다하다  210
# 장갑 끼고 영상보다 하다 다시보다 또 장갑을 버리다 다시 끼고 반복하다 그래도 재미잇다  215
# 처음 시작하다 사람들이 보기에는 정확도가 떨어지다 특히 많다수강생이 겪다 있다갈라지다 현상이 있다플루이드를 많이 사용하다 그런거라고 답변하다 처음에 알다 양에서 그렇다문제가 생기다 양을 수정하다 알다 샤맞다 않다 싶다  217
# 궁금하다부분들을 상세히 설명해주다 이름만 듣다 정보가 전혀없다이해가 쏙쏙되다  218
# 레진 코스터는 영상만 미리 보고아직 작업 전인데 정말기대다 요 226
# 살짝아쉽다 있다일반 피코 사이즈도 함께 알다 더좋다 같다 239
# 제가 너무 손재주도 없다처음 접한 사람이라 그렇다 있다크리에이터님이 너무 전문가 시라 동영상이 초급자가따르다 하다 자세하다보다 하다 부분은 안보이고 설명해주다 부분이 저한테는 어렵다기본을 쌓다 신청하다 하다 하다 생각이 들다 유튜브 검색도 해보다 책도 구매하다 아무래도 직장인이라 단시간엔 따르다 힘들다 같다다른 강의도 결제하다 배우다 중이지만 어렵다 240
# 첫 링을 만들다 때 모양을 보이다 주지도 않다 다음 링을 만들다 때의 방법 이건 초보가 배우다 건지다 중급자가배우다 수있다건지다 알 수없다환불도 못하고 유투브 보고 연습하다 말이 되다  241
# 얇다사용하다 실이 자다 안보 여요 실로 마무리하다 부분은 머리 부분으로 실을 넣다 하다 확대하다 보여주다 더좋다것같다ㅠ 242
# 어렵다차근차근알다 좋다 248
# 어렵다연습을 통해탄탄하다쌓다 갈수잇다 같다 251
# 기본기가 확실하다알송 달송한 부분인 곳이 속이다 후련하다 253
# 아직 처음 접하다 거라 생소하다기대되다 ㅎㅎ 259
# 초보지만 자다 따라가다 디테일 한부분까지 챙기다 설명해주다 굿굿 265
# 저번 클래스는 베이직이다 요번에는 심화 버전인 것같다클래스 특성상수 기법이 어려워지다 온라인으로 배우다 힘드다멘티 쌤이 새심하다보너스 영상까지 따로 올려주다 크다 어려움없이 수업을 재미있다수강하고 있다 280
# 설명을 너무 잘해주다 따르다 어렵다않다 재미있다 313
# 멘티 선생님 수업은 앞으로 계속들다  314
# 재밌다계속 진행하다 요 320
# 수업 시간이 길다않다 짧다시간의 투자로 도 성취 감을 느끼다 있다 차분하다쌤의 목소리 덕분에 더 힐링되다 느낌이다 327
# 막바지로 달려가다 있다 예쁘다 다양하다작품을 만들다 믿어지다 않다 너무 신나다 행복하다시간들이다  330
# 시간가다 모르다 계속하다 되다 하나씩완성되다 때마다 감격너무 재밌다 331
# 하다 모양이 잡혀가다 재밌다제법예쁘다만들어지다 정말즐겁다 333
# 조금씩 다양하다패턴이 들어가다 헷갈리다기도하다 조금힘들다해도 완성되어다 모습이 너무 뿌듯하다 재밌다설명을 정말잘해주다 어렵다않다 따라가다  334
# 상세한 설명과 뛰어넘다 없이 순차적으로 진행하다 손이 느리다저에겐 딱이다 339
# 선생님 강의가 차분차분 스텝 바이 스텝으로 진행되다 초보자도 이해하다 용이하다서로 스튜디오 마크라 메 완전 화이팅이다 345
# 너무 재밌다벌써 마지막 수업앞두다 이써다  349
# 벌써 강의 마지막이 다가오다 아쉽다ㅠ 350
# 너무 재미있다시간가다 모르다 하다  353
# 아직 까지는 무리없이 진도자다 나가다 있다 355
# 상세히 설명해주다 빠르다만들기에 적응하다수있다 357
# 꼼꼼하다 차분하다설명해주다 따라가다 초보도 어렵다않다  359
# 알아듣다 쉬다 진행 속도가 빠르다않다 좋다 370
# 어렵다부분도 차근차근알다 피드백도 바로해주다 너무 좋다 376
# 입문분들이겐 조금빠르다이 수업말고 입문 용수밍님수업듣다 들다 쏙쏙들어오다  380
# 예쁘다도안들을 차분하다알다 재미있다만들다 ㅎ 389
# 동영상으로 설명도 해주시고 아래 설명도 캡쳐하다 설명이 되어다 있다 좋다미션하다 부족하다부분도 자다 알다 너무 좋다 399
# 그림 알지 못하다 사람도 충분하다즐기다 하다 수있다계속 용기를 주다 강의 402
# 댓글의 질문을 빠르다답해주다  415
# 선생님의 편안하다목소리와 아름답다플러스 펜 수채화 그림 그리기 시간은 삶의 희망을 주다 시간이 되어다  419
# 그림을 그리다 스트레스가 풀리다 휴식같다시간이 되어다  421
# 설명이 친절하다 자세하다 좋다다만 나중에 기간이 끝 난후를 대비하다 수업 노트를 다운받다 수업 노트는 내용이 좀부족하다 같다ㅠㅠ바느질이 좀어렵다도안에는 없다요 432
# 차근차근따르다 하다 수있다1부터10까지 자세하다알다 어렵다보이다 다시 반복하다 보여주다 굉장하다쉬다 보고따르다 하다 수있다b 440
# 이게 정말되다 하다 초보자도 똑같이 만들다 수있다점점 실력이 늘다 느껴지다  441
# 어렵다않다 쉬다 설명해주다 좋다다만 키트 배송이 늦다 오픈되다 강의를 못들다 아쉽다ㅠㅠ 444
# 일단 완성되다 인형들이 너무 귀엽다그리고뜨개질 초 보임에도 차근차근 설명해주다 어렵다따라가다 있다시간도 잘가다 추천 추천 해요  446
# 처음 접하다 분들도 잘하다 있다 자세하다설명하다 주다 재밌다만들다 있다코로나 시기에 힐링되다 1000프로만족하다 450
# 하나 하나 설명을 잘해주다 많이 어렵다보이다 자다 따르다 하다 같다감사하다  451
# 글자 로만보다 자다 모르다 부분을 확실하다알게 되다 디테일의 차이 하나 하나가 인형의 느낌을 다르다만듭니다 만들다 동안귀엽다연발하다 완성의 순간을 기대하다완성 후에는 실을 더 구매하다 검색하다 되다  452
# 온라인이라 잘하다 어느정도 느낌이여 야하다가늠이 잘안되다인형 안에 들어가다 솜의 무게를 알다 크다 도움이 되어다 인형 완성작사이즈도 알다 주심 좀더 도움이 되다 않다 싶다 요 454
# 자세하다설명이 어렵다않다 따라가다 수있다 460
# 넘다 넘다 귀엽다만들다 내내즐겁다 464
# 상서하다 설명해주다 하나도 어렵다않다  468
# 바느질은 아직 어설프다 어렵다인형이 완성되다 신기하다 재밌다 470
# 자세하다설명 덕분에 어렵다않다 인형을 만들다 있다 479
# 처음하다 설명을 천천히 잘해주다 자다 만들다  495
# 차근차근 설명을 반복하다 해주다 이해가 빠르다되다 것같다 496
# 어렵다설명도 꼼꼼하다자다 따라가다 있다 재밌다 497
# 반복으로 영상을 재생하다 되다  506
# 어느정도 어디까지 깍고 밉다건지다 센치나 두께 크기나타내다 멘트가 알다 없다영상속이미지로 계속보다 되다 이미지도 전체적으로 앞뒤 옆 위아래 제대로되다 이미지가 없다처음하다 초보에게는 어려움이 있다 518
# 디테일 샷이나 여러 각도의 화면이 없다 아쉽다그리고카 빙하 면서 자꾸 화면 아래로 내려가다 카빙을 자세하다볼 수없다 아쉽다 519
# 차근차근 진행해주다 좋다다만 조금 더 구체적으로 알다 좋다예를 들다 깎다 전에 포크 날을 어느 지점부터 어느 지점까지 어떠하다모양을 목표로 깎다 몇 미리혹은 센치또는 13지점 등 조금 더 구체적인 지표가 있다깎다 어느정도 머리 속에 더 모양이 잡히다 것같다 520
# 어느부분을 얼만큼 깎다 모르다  526
# 16영상은 같다영상이 반복되다 것같다강의가 전반적으로 설명이 빈약하다편이라 아쉽다 534
# 제가 곰손인데 다 피드백이 안되다 아쉽다 안되다때마다 계속하다 재생하다 보다 좋다 539
# 수업 내용에 따르다 하나씩하다 보다 어렵다않다 원하다만들다 있다 좋다 540
# 보통 이상정 도로 진도는 적절하다구성되어다 자세를 알다 부분이 좀부족하다생각되다  541
# 설명도 친절하다 자세하다해주시고 선생님 음성도 넘다 듣기좋다 어렵다하나씩하다 재밌다성취감다 느껴지다 ㅎㅎ멋지다수업이예요  544
# 과제 피드백을 하나 하나 해주시는 것같다 든든하다설명은 간결하다 적확하다목소리도 듣기편하다따라가다 수있다것같다 545
# 설명을 너무 자다 해주다 그렇다수업 진행따라가다 문제도 없다너무 재밌다 547
# 어렵다상세하다 설명되어다 즐겁다하다 수있다 551
# 설명을 자세하다해주다 수업이 힘들다않다  556
# 꼼꼼하다알다 주신대로 진행하다 어렵다 없다 즐겁다즐기다 있다 562
# 선생님께서 만들다 모습을 보다 따르다 해보다 좋다것같다 568
# 설명대로 시간을 갖다 해보다 자다 따라가다 있다 579
# 도구 하나 하나 사용 방법이 자다 설명되어다 습다  581
# 아직 까지 어렵다면은없다만들다 두려움이 없어지다  594
# 순서대로 마무리잘하다 성공 604
# 어렵다느껴지다 레진 공예에 대해서 쉬다 자세하다설명해주다 따르다 좋다수업이에요  608
# 궁금하다부분을 여러번 볼 수있다 궁금하다부분 위주로 먼저보다 집중 도도높아지다 ㅋㅋ 609
# 레진 공예를 처음하다 사람도 어렵다않다 따르다 하다 수있다 자세하다 친절하다설명을 해주다 좋다 610
# 레진이 초보 라면쉬다 이해하다 같다경력자라다 조금은 아쉽다 같다느끼다 한데잘보다 있다 616
# 선생님의 피드백도 너무 좋다답변도 빠르다영상 미도좋다 나긋나긋하다목소리에 힐링도 되다 ㅎㅎ작업은 물론 수업 퀄리티도 좋다 623
# 초보자의 눈높이에 맞다 자다 설명해주다  637
# 너무 재밌다다음 수업이 점점기대다 요 639
# 어렵다너무 예쁘다 재미있다 642
# 1짧다핵심만 말하다 강의2선생님의 정확하다일관적인 딕션과 안정적인 톤 정돈되다 분위기3향에 대한 지식을 알다 재밌다 657
# 가이드조향과 베리 에이 션조향을 통해익히다 향기들을 바탕으로 원하다향기를 찾다 직접만들다 보다 즐겁다시간이다  661
# 조향을 해 볼 수있다것에 신기하다 재미있다 친절하다간단명료하다강의가 더 더욱 수업을 듣다 만들다 만들다 것같다 669
# 향수가 아니다개개의 향료들을 맡다 본적은 없다 저렴하다원료가 아니다고급스럽게 느껴지다 강의의 재료는 가브리엘님께서 신경써다 챙기다 것같다수업 시작 전 고민하다 시간이 아깝다정도에요  670
# 오아직도 수강 신 청 안한 사람있다낭여 망설이다 필요없다따다 고급 진쓸다 쌩님과 고급 진 향기의 세계로 고곡 675
# ㅋㅋ귀에 쏙쏙 과외받다 느낌이다설명도 어렵다않다 해 주시고  678
# 전공자가 아니다때문에 조금어렵다답변도 빠르다기초부터 탄탄하다배우다 수있다 679
# 피드백도 빠르다주시고 강의도 자다 따라가다 있다해주다  696
# 궁금하다점이나 어렵다부분은 바로바로 그림까지 그리다 알다 서너무좋다 706
# 선생님 강의가 지루하다 않다 계속빠져들다 같다너무 재미있다 721
# 직접 마법을 창조해내다 것에 있다크다 만족감을 느끼다 내 머릿속에만 떠다니다 마법이 형태와 힘을 가지고 곁으로 찾아오다 것같다 726
# 댓글 피드백이 즉시들어오다 수업 영상을 통해 현재의 작업을 수업 내용을 통해 미래의 작업을 준비하다 수있다강의이다강사님의 조용조 용한 목소리와 자신의 마법을 들여다보다 수업 내용이 단순하다목공을 위한 시간이 아니다나 자신을 들여다보다 명상의 시간과 잊다 꿈을 되찾다 시간이 되다 하다  729
# 아무래도 각자의 것을 만들다 보다 추상적인 설명이 주가되다 것은 어쩔 수없다하다 사람하다 사람의 디자인을 일일이 검수하다 주시고 어렵다부분은 조언도 아낌없이 해주다 겁먹다 않다 따라가다 수있다 733
# 하나 하나엄청 자세하다알다 나무를 조금씩 깎다 갈다 때마다 무척이나 즐겁다눈에 보이지않다 꿈을 만들다 그 형태가 보이다 거같다무척이나 재밌다 734
# 6가지 모두너무 재밌다기본 베이스는 다 같다두번 정도면 좀더빠르다하다 같다 새롭다비누나오다 때마다 신기하다 748
# 동영상을 보고하다 별다르다궁금증이 없다만큼자세하다 760
# 설명이 자세하다따르다 좋다아동 용 부터 시작하다 난이도쉽다부분부터 차근차근하다 보다 어렵다성인 용도 무난하다 하다 수있다완성 품의 디자인과 퀄리티도 좋다실용성있다 761
# 오프라인에서 일일이물어보다 어렵다부분이 있다상세한설명을 반복하다 들다 훨씬 이해가 잘되다  765
# 친절하다세심한 설명 덕에 혼자 서도어렵다한복을 예쁘다만들다 수있다 766
# 초보가 듣기에 수업도 수업 자료도 너무 간결하다 771
# 늘2부족하다부분을 이젠확실하다알게 되어다 답답하다해소되어다 지금까지 수강신청은 자다 하다 스스로 칭찬하고 있다재봉에 재미가 나다  776
# 피드백짱이다모든 글에 답변을 자다 해주시고 격려와 칭찬을 아끼다 않다  782
# 고급 진 마무리로 직접만들다 옷들이 더욱소중하다ㅡ 795
# 차근차근하다설명으로 수업 내용을 자다 이해하고 따라가다 수있다수업이다 800
# 미션 댓글에 피드백이 빠르다편이어서 자다 못되다 부분이나 궁금하다부분을 빨리 알 스있다 801
# 프로그램을 자다 사용하다 수있다 좋다것같다나만의 도안을 만들다 활용하다 면에서도 좋다 807
# 차분하다알다 좋다 다양하다해보다 수있다 좋다것같다막상해보다 어생각보다 쉬다 이렇다수있다그 노하우를 모르다 빙빙돌아가다 건데강의 듣기잘하다 생각이 들다 토퍼를 직접만들다 볼 수있다수정해보다 수있다 좋다만들다 레이어에 대한 이해를 하다 수있다너무 좋다다음 강의가 열리지않다 ㅠㅠㅠㅠ얼른올라오다 좋다 808
# 온라인이라 걱정하다 동영상을 계속돌리다 보다 부족하다부분을 계속 연습하다 수있다 816
# 세심한 작업이 많다것같다가방이나 지갑이 기대되다  817
# 짧다수업 시간이 집중하다 수있다해주다 편안하다수업하다 수있다만들어주다  823
# 차분하다나만의 시간을 가다 수업을 재밌다따라가다 재미가 있다 행복하다 824
# 차근차근예쁘다목소리들다 따르다 금새만들다 있다 어렵다않다 자다 설명해주다 쉬다 따르다 하다 수있다힐링 클래스이다 825
# 설명만 나오다 게아니다엘 선생님도 그리고채색하다 같이 그림그리다 것같다 826
# 색연필을 처음가다 볼 만큼 그림에 소질도 없다못하다 거라는 두려움이 있다기초적인 것 부터 차근차근 설명하다 주다 게좋다마음을 차분하다만들다 목소리도 좋다 828
# 친절하다 따뜻하다느낌의 수업이예요 어르다 살아가다 애쓰다 어른에게 아이같다감수성을 되살리다 마음이 편안하다시간같다 830
# 그림이 입체가 되다 과정이 특히 재미있다 즐겁다금방질리다 성격이라 뭐든 꾸준하다자다 못하다 수업너무 재미있다 부지런하다듣다 있다 831
# 너무 너무 재다 영상도 너무 아름답다 835
# 시간가다 모르다 오다 집중하다 돼다  837
# 수강 기간이 기다 안심하고 따라가다 수있다다행이다 843
# 그런데내용적인 부분에서는 빈약하다 같다 844
# 옛날에 한번이르다 수업을 받다 적이 있다그때는 당시 선생님이 너무 복잡하다가르치다 어렵다툴이라고 생각하다 이 수업은 쉬다 하나 하나가르치다 주어서 천천히 따라가다 수있다감사하다  846
# 동영상이 채다 터 별로나뉘다 지루하다 답답하다않다 그리고설명이 쉬다  847
# 자세하다설명으로 차근차근따라가다 수있다 좋다그런데색상값을 말로만 들어서다 여러번들다 색상값을 수업 노트에 싸주다 좋다것같다감사하다  848
# 크게어렵다않다 차근차근알다 좋다 853
# 매 차트마다 자다 설명해주다 좋다아직 바느질이 어렵다계속하다 나아지다  863
# 하나 하나자다 따라가다 수있다알다 좋다것같다 867
# 속도를 맞추다 작업을 진행하다 수있다 좋다피드백도 좋다 868
# 꼼꼼하다 차분하다자다 설명해주다 영상 보고 만들기어렵다않다 설명만 자다 따라오다 예쁘다명화가 비누 속에 쏙들어가다 ㅎㅎ 872
# 궁금하다혼자 해결하다 없다물어보다 해결하다  876
# 제과제빵이라 하다 어렵다느껴지다 선뜻 시작하다 힘드다덕분에 쉬다 편하다배우다 ㅎ 889
# 헷갈리다만들다 영상에 필요하다재료가 적히다 좋다오다 가다 하다 되다  891
# 클래스101에 있다수업중에 고민하다 제일 마음에 들다 걸로 골라서 수강중인데 수강하다 잘하다 같다 893
# 스패츌러 활용하다 매끈하다만들다 방법이랑 캐릭터 표현하다 방법알다 좋다 899
# 간단하다너무 예쁘다그리고여러 과일들로 다양하다만들다 있다 좋다 901
# 공정을 자르다 않다 그대로찍다 선생님과 같이 하다 재미가 있다 같다 905
# 질문에 답도 빠르다해주시고 과정도 하나 하나천천히 보여주다 초보자들이 보기엔 좋다 906
# 단순하다작업들을 너무 오랜시간보여주다 시간채우다 같다느낌이 듭니다  909
# 차근차근알다 너무 좋다속도도 빠르다않다 적당하다진행해주다 보다 하다 좋다ㅎㅎ 912
# 차분하다따르다 아직 까진 어렵다부분이 없다자막이 있다도움이 되다  913
# 수업 노트도 포인트 포인트 정리자다 되어다 영상도 부분 부분자다 나뉘다 만들다 헷갈리다부분찾아보다 좋다 914
# 이해하다 쉬다 설명하다 주다 좋다지금까지는 어렵다않다 따라가다 있다 좋다 917
# 간단하다완성도 높다작품이 완성이 되다 얼마 전에 페이퍼 플라워 도서를 한권사다 선생님께서 얼마나쉬다 간편하다만들다 있다노력하다 바로 알게 되어다 수고많다 919
# 디테이다 자다 설명해주다 같다근데 중간 중간에 철사23호이렇게 보단 얇다철사23호라고 해주다 더쉬다 같다 921
# 너무 이쁘다결제하고 이틀만에 완강하다 빨리 재료가 오다 만들다  930
# 영어로 진행되다 한글 자막도 있다 어렵다않다 그리고강의 록이 아래에 그대로적히다 하다 번읽다 영상을 보다 더쉬다 하다 수있다진짜 꽃처럼예쁘다영구적으로 보존하다 수있다 아름답다꽃을 만들다 수있다 좋다배우다 두다 선물하다 때 응용하다 좋다것같다 934
# 꼼꼼하다자다 설명해주다 좋다그런데중요하다부분들은 조금 확대하다 보여주다 더좋다것같다 937
# 천천히 자다 설명해주다 하지만영어로 설명을 해주다 미리 한번본뒤 복습하다 방법으로 하다 하다 듯하다 아직 실전으로 만들다 보다 않다 왠지 기대되다 완성 물이나오다 듯하다  940
# 상세하고 꼼꼼하다알다 따르다 기도어렵다않다  948
# 설명이 자세하다따르다 어렵다않다 좋다 949
# 넘다 빠르다않다 적당하다속도로 설명해주다 이해가 빨르다 951
# 쉬다 어렵다않다 따르다 하다 수있다 좋다 960
# 여러각도에서 보여주다 연습하다 사진을 올리다 피드백도 굉장하다 빠르다그리고아낌없다칭찬을 해주다 연습이 즐겁다 966
# 다른 각도에서 앙금짜다 모습보여주다 많다도움이 되다 같다선생님께서 피드백도 잘해주다  972
# 아직 다 준비가 안되다잘모르다 ㅠㅠ제가 재료를 다 준비못하다 빨리 해보다 잘하다 있다ㅠㅠ 973
# 끝을 올리다 말씀하다 것 때문에 답답하다느낌도 들다 집중 도가 많이 떨어지다 ㅠㅠ 977
# 앙금짜다 모양이 여러가지라 응용하다 낞을꺼같다 982
# 재밌다영상이나 흐름이 어렵다않다 초보자도 충분하다따르다 하다  999
# 천천히 반복하다 각도다르다보여주다 도움이 많이 되어다  1000
# 천천히 하나 하나 설명해주다 좋다조금 더자세하다알다  1013
# 어렵다않다 가르치다 주다 좋다단점은 크게없다것같다 1022
# 떡이 어렵다생각하다 쉬다 계량도 자세하다따르다 쉬다  1031
# 하나 하나 미션을 하니 더 진도가 자다 나가다  1033
# 처음 부터쉬다 알다 따르다 하다 어렵다않다  1041
# 너무 너무 재밌다아직 익숙하다않다 완성 도가 떨어지다 하다 하다 익숙해지다 ㅎㅎ 1052
# 영상을 보다 하다 어렵다영상 먼저 보고 또 한번보다 만들다 하다 만하다  1053
# 무언가를 하다 때 이유를 말해주다 허다 그냥이렇게 하다 느낌이에요 설명이 부족하다느낌 1054
# 천천히 같이 하다 수있다것같다지금은 미리 한번 보고 두번째만들다 준비하고 있다 1055
# 어렵다하지만완성하고 뿌듯하다느껴지다 좋다네용 1062
# 트레이스 정도를 캐치하다 어렵다빼다 괜찮다 1066
# 과정을 하나씩보여주다 따르다 어렵다않다  1067
# 정말 기본적이지만 비누가 어떻다만들어지다 알게 되어다  1072
# 새롭다풍선 만들기 재미에 푹빠지다 애들도 좋아하다어른도 만족하다 있다수업이다 1078
# 어렵다않다 자세하다설명해주다 하나 하나 계속되다 짚다 알다 넘다 좋다 1084
# 온라인 수강이라서 피드백 부분이 가장걱정스럽다부분이 이다 괜한 걱정을 한것같다랄라 쌤 강의는 오프라인 강의같다ㅋㅋㅋ 1088
# 천천히 따르다 편하다설명을 해주다 어렵다않다 만들다 있다 같다 1091
# 아직 물건 아트오기전까지 다 영상을 봣어요 빨리 만들다 보다  1095
# 차근차근친절하다설명을 해주다 따르다 어렵다않다 근방 작품이 완성되어다 넘다 좋다 1134
# 너무 재미있다설명도 자다 해주다 모르다 반복하다 들다 하니 완성 품을 무리없이 만들다 있다 1136
# 꼼꼼하다설명하다 주다 따르다 어렵다않다  1151
# 설명이 중언부언늘어지다 않다 속도도 적당하다따라가다 어렵다않다  1156
# 직접 대면하다 수업듣다 것같이 상세하다 좋다지금듣다 코바늘 수업 선생님 피드백도 빨라서 좋다공예 수업이 조금 더다양하다많아지다 좋다 1161
# 쉬다 설명해주다 잘하다 있다 같다강의어느것 하나소중하다않다 없다 같다배색 과정이 힘들다완성 후대만족이네 요 가방도 넘다 예쁘다 1163
# 천천히 코바늘 초보자도 알 수있다지도해주다 가방 만들기어렵다않다  1164
# 자세하다자다 설명해주다 어렵다않다 자다 따르다 뜨다 같다디자인도 예쁘다뜨다 내내즐겁다 1166
# 너무 재밌다다만 팁들이 중간에 끼다 경우가 많다한번 쭉훑다 보고따르다 추천드리다 댜 1167
# 무엇보다 바로바로 결과물을 완성하다 사용하다 있다 뿌듯하다실용적이라 좋다 어렵다점도있다강의를 잘따르다 하다 있다설명이 잘되어다 있다 1170
# 어렵다 친절하다설명으로 따라가다 감사하다  1179
# 친절하다 자세하다알다 쉬다 설명해주다 어렵다느끼다 않다  1186
# 초보자에게도 이해가 자다 되게 수업을 해주다 이해도가 높아지다  1204
# 마무리 강의까지 완벽하다 1209
# 차근차근 진행해주다 동영상 재생을 멈추다 다시 재생하다 듣다 어색하다않다  1215
# 차근차근세다 자다 설명해주다 어렵다옷임에도 자다 따라오다 수있다 1220
# 따르다 전 미리 보고 눈에 익히다 후 작업을 하다 보다 조금 더친숙하다느끼다 수있다 좋다그리고선생님의 친절하다설명이 이해도를 더높이다 같다만족이다 1221
# 한복 만들기하다 꼭해보다 싶다 품목으로 진행되다 수업이라 좋다 1228
# 동영상과 설명을 잘해주다 초보인데 도 잘만들고 있다 1229
# 상세하고 차근차근하다설명해주다 이해가 자다 되다 다만 혼자서 하다 초보여서 조금어렵다하지만그래도 방 구석에 앉다 이렇게 하다 수있다너무 좋다 1237
# 어렵다부분들은 반복하다 보다 수업 진행을 하다 좋다 꼼꼼하다 차분하다수업을 자다 진행하다 주다 자다 따르다 하다 있다 1239
# 선생님이 친절하다항상 답변해주다 도와주다 예시도 먼저보여주다  1240
# 쉬다 가르치다 따르다 어렵다않다 똥손도 따르다 하다 수있다 1241
# 꼼꼼하다가르침으로 초보자도 어렵다않다 따르다 하다 수있다넘다 좋다 1249
# 차분하다설명과 어렵다부분도 화면을 크게잡다 햇 갈리면 반복하다 자세하다볼 수있다 좋다 1256
# 설명이 자세하다나오다 어렵다않다 재밌다수업이에요  1257
# 어렵다부분 질문하다 때 바로 대답해주다  1259
# 재료 준비가 잘되다 귀차니즘 쩌는 사람도 하다 있다 1260
# 모르다 사실들을 알게 되어다 도움이 많이 되다 같다말의 속도가 너무 빠르다하다  1264
# 퍼스 널 브랜딩에 대해막연하다워크다 시트와 선생님 수업 내용 참고하다 정리하다 가다 시간이다  1266
# ㅎㅎ조금어렵다기다 오다 맞다 그렇다 그렇다머리를 딱치다 느낌을 많이 받다  1271
# 하나 하나 과정을 짚다 강의채다 터가 넘어가다 과정 중간에 전반적으로 정리하다 있다시간을 제공해주다 생각을 정리해보다 있다해주다  1277
# 깔끔하다정돈되게 정리하다 알다 쏙쏙 머리 속에 들어오다 들다 수록 수강하다 잘하다 생각이 들다  1280
# 진짜 모두가 들다 좋다가치있다수업이네 요 돈이 전혀아깝다않다  1286
# 앤드류님의 직접 경험을 바탕으로 실질적인 꿀팁과 틈새 공략들이 너무 흥미롭다수업 자체 내용이 흥미롭고 재미있다 1294
# 대충하다 없다채다 터의 미션이 다시 한번 강의를 곱씹다 하다 아직도 맘에는 안들지만 또 다시들다 또하다  1295
# 모르다 부분을 알다 과정이 너무 즐겁다아직 은멀다차근차근 준비중이에요  1296
# 세다 코칭이라는 생각이 바로 드네요 어렵다않다 지루함도 없다너무 좋다 1297
# 인스타그램을 사용한 지다 오래되다이렇게 상세한 내용을 모르다 지나치다 많다영상을 통해많다도움이 되다 있다 1298
# 단순하다인스타그램을 성장시키다 아니다퍼스 널 브랜딩을 통한 소셜미디어 활용은 내가 좋아하다일로 돈을 벌 수있다시대에 꼭필요하다능력 이기 때문에 퍼스 널 브랜딩의 중요성을 강조한 강의가 차다 오다 닿다 클로이좋다크리스4명을 예시로 인스타그램 성장시키다 과정을 알다 때문에 저처럼 인스타그램 방향 설정 기능에 익숙하다않다 사람도 비교적쉬다 강의 내용대로 인스타그램 퍼스널브랜딩을 하다 수있다내가 좋아하다분야를 찾다 그것을 어떻다남들에게 표현하다 하다 모르다 분들에게 인스타그램 퍼스 널 브랜딩 강의 추천하다  1299
# 기본이 중요하다것이렇다저런 방법도 있다가장 중심이 되다 건 가치있다콘텐츠라는 부분이 오다 닿다 강의이다 1302
# 정말 디테일한 실전 적용 내용들을 알다 개인받다 느낌이 들다 정도로 요ㅎㅎ다른 클래스에는 없다진정성이 느껴지다  1304
# 따로 학원을 가야한 다 던지다 그렇다필요도 없다영상이 막 하나당한시간씩그런것도 아니다보기편하다 좋다제가 2020년에사다 중 젤 맘에듭니다  1305
# 강의만 듣다 되다 아니다나름 뭔가를 구축하다 하다 답답하다강의를 신청하다 조금은 알다 같다 1306
# 적용하다 효과가 조금이라도 바로나타나다 내가 돈주다 강의받다 중에 제일만족하다 1312
# 생각 지도 못한점 어쩌면당연하다인지하다 어렵다부분을 자다 설명하다 주다 같다 1319
# 짧다세다 하나씩집다 강의라서 부담없이 듣기에도 좋다단번에 팔로워가 확 늘 수는 없다나에게 맞다 속도로 직접 시도하고 강의를 다시들다 놓치다 부분을 보안하다 올리다 있다과정을 밟다 성장하다느낌이다 1322
# 이런클래스없다어쨌겠냐 싶다 정도 유트브로 먼저 접하다 별다르다잇다 며 생각도 햇지만 혹 시나하고 그리고반드시해내다 햇기에 신청하다 너무 너무 칭찬하다  1323
# 간결하다포인트를 정리해주다 이해에 도움이 많이 되다 특히 예시로 만들다 인스타에 가상인 물다 크다 시트이런걸보다 준비많이 하다 성의있다강의로 느껴지다 더많이 신뢰가 가다  1324
# 직접적으로 부딪히다 하다 인스타그램막막하다계속중요하다부분들을 얘기해주다 되다 짚다 주다 초심잃다 않다 자다 따라가다 있다 1325
# 사람이 사람의 마음을 얻다 진실로 어렵다일이며 sns상에서 나르다 믿다 좋아하다사람을 만나다 크다 행운이듯하다 단순하다내계정의 팔로워좋다숫자가 아니다나의 가치와 내가치를 알아주다 사람들의 가치를 존중해주다 한다는걸배우다 누군가를 탓하기전에 나의 컨텐츠꾸준하다 성장하다모습을 담다 야하다진심어리다 메세지가 담기다 강의를 여러번돌리다 보다 조금씩 조금씩 성장해보다 하다  1326
# 인간미가 느껴지다 인스타라는 sns계정이 주다 나의 가치를 다시금 생각하다 해주다 무엇보다 앤드류님의 사고방식과 그의 체계적인 수업 방식이 인생 멘토급이다 1328
# 강사분이 댓글 피드백이 없다확인을 자다 안하다 것같다 1331
# 이 강의를 들다 인스타에 관해 무적이 되다 것같다 1334
# 생각하다 못하다 부분들을 이야기하다  1348
# 조금 더명확하다가이드라인이 필요하다 많다도움이 되다  1356
# 구체적이고 현실적인 방법이다도움많이 돼다  1357
# 동안막연하다알다 내용이 정리되어다 있다 1358
# 놓치다 부분들을 다시 체크하다 볼 수있다 중요하다수업이 이다  1359
# 정리깔다 끄다 인스타 초보자를 위한 완벽 정리 1377
# 들다 들다 저의 브랜드를 어떻다만들다 야하다그려지다  1386
# 구체적인 4개의 계정을 예시로 들다 수있다 1395
# 처음 시작하다 때는 분명 재봉틀 실끼우다 어렵다하다 이제는 옷 다운 옷도 만들다 수있다되어다 강사님이 차근차근따라오다 만들다 수있다하다 실제로 이루어지다  1415
# 설명을 세다 잘해주다 빠르다 적응하다 있다 1427
# 차분하다 자세하다설명이 좋다 어렵다않다 배우다 수있다 1437
# 구체적인 설명과 아름답다작품이 자다 어우러지다  1438
# 차근차근 진행하다 편하다하다 수있다 1447
# 상세한 설명 이미지를 활용한 설명 등이 좋다 어렵다않다 수업을 따라가다 수있다 1450
# 친절하다설명에 처음인데 도어렵다않다 너무 재미있다 1452
# 시간가다 모르다 만들다 시들다 않다 이쁘다꽃들이 주위를 밝다 해주다  1458
# 저한테는 기다리다 기다리다 하루 힐링 타임이라 너무 행복하다제 손에서 무언가만들어지다 자체가 기분좋다더군다나 제가 원래 꽃을 무진장좋아하다 예쁘다기간이 얼마없다항상슬프다피오니 클래스는 질리지 않다 시들다 않다 영원하다이상적이예요 더군다나 크라프트지를 가지고 만들다 좀 더단단하다느낌이라 초보자가 만들다 안정적다 같다꼭 중급자 클래스도 만들다 바래 보다  1461
# 손으로 만들다 강사님보다 좀 정신이 없다일단 한번 흐름을 듣다 다시 스탭스탭맞추다 하니 좀 이해가 빠르다 같다 1464
# 생화와 비교하다 손색이 없다오히려 더오랫동안 예쁘다유지하다 수있다꽃이예요  1466
# 쌤이 설명해주다 함께 꽃만들다 과정을 같이 해주시니 어렵다더욱쉬다 하다 되다 이쁘다꽃함께 만들다  1467
# 조금어렵다하지만완성하다 때마다 뿌듯하다크다  1473
# 차분하다설명을 잘해주다 과정을 따라가다 전혀 문제가 없다두번째 수강인데 정말만족스럽다클래스이다  1485
# 결과물이 남다 좋다것같다한땀한땀놓다 마음도 편하다지다  1486
# 수업을 통해새롭다스티치를 알게 되다 키링 컵 받침 등만들다 반복되다 연습으로 자수놓다 방법을 손에 익히다 볼 수있다크게어렵다않다 작가님께서 쉬다 설명해주다 수업을 따라가다 힘들다않다 또한 댓글을 통해 즉각적인 피드백을 받다 직접 작가님께서 코칭해주다 것처럼 오프라인 수업 느낌도 받다 수있다 1488
# 시간이 오래 걸리다 작업을 천천히 이다 갈다 수있다만들다 수업이에요  1492
# 처음이라 어리다 같다쉬다 또쉽다 어렵다 같다하다 아마도 제가 똥 손 인가보다 ㅎㅎ하다 하다 매력이 있다너무 재미있다 1502
# 차근차근 설명이 너무도 도움되다 이해도편하다 궁금하다점도바로바로 대답해주다 함께 진행하다 기분이 들다  1511
# 내용 설명하다 때충분하다따라오다 수있다천천히 말씀해주다 세심하다 영상으로 보여주다 마크라 메 온라인 수업으로 짱이에요  1513
# 쉬다 자세하다설명으로 따르다 어렵다않다 빠르다완성되다 작품을 보다 행복하다 1514
# 마크라 메어렵다생각하다 쉬다 설명해주다 따르다 하다 좋다단시간에 만들다 악세사리들도 넘다 좋다더여러개배우다 나만의 팔찌나 귀걸이를 만들다 보다  1515
# 설명도 천천히 자세하다해주시고 준비물도 자다 챙기다 무엇보다 어렵다않다 결과물도 바로바로 나오다 너무 재밌다 1516
# 선생님이 명확하다안내해주다 커리큘럼이 알차다 재밌다조금어렵다 헷갈리다여러번돌리다 보다 엮으면 어느새다 예쁘다악세사리가 완성이다 1525
# 빠르다피드백과 적절하다속도로 수업이 재미있다 지루하다않다 스스로의 성취 감을 이루다 수있다자다 소통하다 주다 만족하다 1532
# 아직 키트를 받다 않다 상태로 영상을 보다 이해가 정말잘되다 세다 부분까지 신경써주다 수업을 해주다 부분이 좋다 1538
# 재미있다처음엔 어렵다하나씩이 작품이 늘어나다 실력도 늘다 뿌듯하다 1549
# 기초이니 만큼 키트가 도착하다 않다 차근차근천천히 설명하다 주다 눈으로도 공부가 돼다 키트가 기다려지다  1560
# 내가 만들다 팔찌나 반지가 예쁘다더 애착이 가다 것같다 1570
# 차근차근 설명해주다 어렵다않다 완성시키다 수있다 좋다 1571
# 넘다 넘다 재미있다또다른과정이 나오다 또하다 예오 1574
# 어렵다않다 자세하다설명이 좋다 1575
# 설명도 자다 해주시고 답변도 자다 해주다 그리고재미나다  1583
# 개미지옥같다강의넘다 재다 시간가다 모름 1589
# 신나다취미가 생기다 조어요 ㅋㅋㅋㅋ 1595
# 조 근 조 근자세하다설명과 예쁘다만들다 팁 등유익하다수업이네 요 1604
# 차분하다 자세하다설명 덕분에 온라인수업인데 도어렵다않다  1605
# 너무 잘이다 주시고 잘 못되다 부분 체킹도 잘해주다 만족 완전굳다 1630
# 막상해보다 짧다시간에 간단하다완성되어다 지치다 않다 재미있다 1636
# 질문에 바로 답을 주다 궁금증이 해결되다 남다 연습 1648
# 친절하다설명찬찬하다진행되다 속도가 맘에 듭니다  1653
# 초보자를 좌절하다 하다 않다 클래스 앞으로가 더욱 기대되다  1661
# 수월하다자다 진행되다  1663
# 차분하다만들다 설명도 자세하다 1677
# 혼자이다 알다 어렵다또는 오래 걸리다 모든 정보들과 노하우들을 쉬다 풀다 너무 감사하다  1680
# 단순하다만들기만이 아니다그동안쌓다 노하우와 꿀팁들을 알다 너무 좋다혼자 독학하다 이렇다차다 오래 걸리다 싶다 들이다 있다 1681
# 꼭필요하다채다 터자다 구성되어다 있다 1682
# 강의만으로 부족하다경우가 있다질문을 댓글에 남기다 두다 선생님께서 잊지읺고 답변해주다 피드백도 빠르다편인 것같다 1687
# 결과물이 매우만족스럽다수업 궁금증에 대한 피드백이 빠르다온라인수업이지만 오프라인못지않다고퀄리티 수업이에요  1689
# 정말친절하다자다 알다 난이도가 조금있다것같다그래도 영상을 보다 만들다 보다 재밌다꽃을 완성하다 수있다 1693
# 처음엔 조금어렵다점점배우다 늘다 느껴지다 그만큼 더뿌듯하다재료도 정말넉넉하다맘대로 만들다 수있다 좋다 1696
# 일단재미있다 예쁘다하다 보다 시간이 얼마나지나다 모르다 정도에요 찢어지다 예쁘다 자연스럽다보여서 만족스럽다클래스에요  1698
# 선생님의 피드백도 빠르다 찬찬하다따라오다 수있다정성 다해 주시는 수업이다 1705
# 채다 터2부터 쭉보다 확실하다비 대면으로 동영상 수업이다 보다 설명에 한계가 느껴지다 같다 1706
# 재료가 안오다 아직 실습은 못하다 하나 하나친절하다알다 같다 1714
# 과정을 짧다 짧다끊다 수강하다 편하다과정도 상세하고 주의하다 부분알다 도움이 많이 되다  1716
# 수업이 재밌다선생님 목소리도 차분하다집중도 자다 되다  1718
# 한가지 방법이 아니다여러 방법을 소개해주다  1722
# 설명이 어렵다않다 하나 하나천천히 자다 따르다 하다 수있다 1724
# 베이직 키트 외에 따로 준비하다 재료가 너무 많다 1726
# 섬세하다알다 설명을 자다 해 주심 1727
# 어렵다 재미있다계속 도전하다 되다  1737
# 반복과 정도 편집하다 않다 부가적인 설명을 더해주다 도움이 많이 되다  1742
# 힐링되다 색 하나 하나만들다 알다 어렵다않다  1747
# 처음해보다 눈거라 어렵다너무 재밌다 1752
# 피드백도 빠르다설명도 잘해주다  1756
# 말씀하다 톤이 집중력을 향상시키다 손이 빠르다다시 보기를 몇번하다 그래도 자세하다설명해주다 어렵다않다 배우다 있다 1761
# 가방을 입체적으로 만들다 었어 더 맘에 들다 따라가다 수업이 재미있다 1762
# 멋지다나만의 작품을 완성도 있다만들다 직접 활용하고 선물하다 수있다너무 좋다 1764
# 실의 종류와 재단하다 위한 기초부터 가방 만들기 위한 기 본틀을 잡다 너무 좋다약간어렵다부분도 있다도움은 많이 되어다 그동안너무 고맙다출판 서적 주문하다 있다 1769
# 차분하다 꼼꼼하다설명해주다 어렵다않다 따르다 하다 수있다자다 모르다 부분은 다시돌리다 볼 수있다더좋다보너스 팁으로 알다 가방도 도전해보다 하다  1770
# 내 손으로 직접만들어지다 가방을 보다 너무 기쁘다만들다 과정 또한즐겁다시간이 어떻다지나가다 모르다  1771
# 전혀 해 본적없이 처음하다 상세히 알다 따르다 어렵다않다 피드백도 너무 친절하다해주다 작품하다 때마다 기대감 상승너무 재미있다 1772
# 차분하다알다 감사하다 전 가방 줄 추가하다 바닥 마무리하다 항상어렵다이번 클래스 덕분에 줄 추가는 이제자다 하다 있다되어다  1774
# 차근차근 설명해주다 보고따르다 어렵다않다 자다 모르다 부분은 여러전돌리다 볼 수있다더좋다 1775
# 설명이 조금어렵다부분이 있다동영상이라 되돌리다 보다 복습하다 좋다 1780
# 줄 추가하는 방법도 특이하다 신기하다근데 줄 추가하는 모습이 조금다 클로즈업되다 보여주다 더좋다 같다살짝헷갈리다부분이 몇군데있다 1781
# 차근차근 설명을 해주다 어렵다않다 배우다 있다 1799
# 다른어렵다매듭이 아니다기본 평 매듭만으로 이쁘다가방이 완성되다  1810
# 섬세하다자다 설명해주다 어려움없이 배우다 수있다유튜브로는 배우다 수없다내용이에요 확실하다퀄리티 차이가 엄청 나다  1813
# 너무 재밋게 만들다 신기하다 유용하다정보도 많다전혀모르다 내용들도 있다너무 도움되다 지인들에게 선물도 하다  1815
# 대체적으로 좋다하나 조금 더자세하다알다 주다 좋다 1826
# 실이 안걸리다 빠지다 자다 조절하다 야하다 같다생각보다 어렵다그래도 하다 거보다 이쁘다 1833
# 어렵다않다 잘하다 설명도 친절하다해주다 좋다 1839
# 하나씩차근차근따르다 보다 어렵다느껴지다 한복을 뚝딱만들다 있다인형한복임에도 불구하고 한복 기법을 익히다 있다가장좋다사람한복도만들다 있다 같다도전하다 보다  1845
# 패턴 응용이 가능하다인형 한복뿐만 아니다사람 한복까지 만들다 수있다거같다피드백도 잘해주다 다음 강의도 있다이번 강의 정복하다 다음 강의도 수강하다  1848
# 강의 보고따르다 한복 저고리가 완성돼다 ㅎ인형 한복 만들기 책2권보다 독학하다 꿀팁같다 없다피드백도 없다만들다 포기하다 되다 ㅠ근데 강의들다 차근차근만들다 보다 벌써 치마 만들기까지 오다 ㅎㅎ사진올리다 댓글 달면 쌤이 피드백을 주시니 더예쁘다한복 만들기가 가능하다ㅎ치수재다 패턴 그리기까지 알다 내 아이에게 핏에 딱 맞다 한복을 만들다 있다제일크다 장점이다 1850
# 무엇보다 초보자도 반복하다 때 이해하다 수있다강의 다라는 생각이 들다 인형 한복이라기보다는 한복강의 다라고 생각하다 한복 관심있다분들은 하다 번쯤들다 보다 만한 강의라고 생각 듭니다 말씀하다 때도 명료하다쏙쏙들어오다 ㅎㅎ공부자다 하다 있다 1854
# 막연하다 예쁘다 좋다한복 한복에 관련되다 장신구까지 하나 하나 용도와 유래 등 얘깃 거리와 설명 하나 하나넘다 잘해주다 근데 패턴을 두다 저고리 섭 재단을 하다 때 시접 여유를 어느정도를 주다 자르다 좋다설명이 없다조금헷갈리다외에는 완벽하다그동안너무 수고많다마감되다 때카지 다시 처음부터 듣기하다 첫작품의 문제점을 보완하다 만들기해보다 구요 한복은 옷이 아니다예술이다 1855
# 한복어렵다생각하다 하나 하나따르다 보다 너무 재다 좋다 1859
# 차분하다목소리 때문에 귀속에 자다 들어오다  1871
# 소소하다신경쓰다 강의하다 기다  1875
# 속도가 조금 빠르기는 한데재밌다 1877
# 조슴어렵다해도 계속돌리다 보다 이해가 되다  1883
# 배우다 싶다 배우다 즐겁다조금씩 아쉽다부분도 있다 1886
# 기본적으로 어렵다않다 누구나 따라서만들다 수있다 같다재료도 넉넉하다복습하고도 남아요 매우만족하다 1895
# 하다 방법을 익히다 재밌다만들다 때 잡 생각이 안들다 좋다완성되다 작품을 보다 성취감다 듭니다  1896
# 과정이 너무 어렵다않다 자다 따라오다 수있다자다 설명해주다 성취 감을 느끼다 하다 좋다공예에요  1897
# 만들다 보다 자꾸멈추다 돼다 영상 먼저 쭉 보고 터득한 뒤에 복습하다 직접만들다 보다 하다 있다ㅎㅎ기대감이 더생기다 듯 해요 ㅎㅎ얼른 다시 시작해보다 ㅎㅎ 1899
# 혼자 집중하다 있다시간을 가지다 좋다따르다 너무 어렵다않다 조금씩 변형을 주다 것도 시도하다 재미가 있다ㅎㅎ 1901
# 새롭다공예라 신선하다 어렵다않다 금방 작업 물을 손에 얻다 있다 좋다 1908
# 설명을 자다 해주시고 작업 물도 예쁘다시간가다 줄모르다 작업하다 되다  1937
# 영상을 보고 작업하다 조금의 어려움도 없이 설명을 차다 잘해주다 영상편집도 자다 되어다 있다수업 구성도 좋다것같다 1938
# 상세하고 꼼꼼하다 친절하다설명에 어렵다않다 그리고기분좋다배우다 수있다너무 만족스럽다ㅎㅎ 1940
# 과정마다 천천히 차근차근 속도 조절없이 진행해주다 선생님을 따라서 작업하다 느낌이에요 따르다 부담스럽지 않다 작업 물도 넘다 예쁘다 1946
# 위빙 수업 중 가장재미있다 1969
# 동테이프자다 감다 방법과 같이 설명이 좀 더 상세하다 좋다그리고액체 플럭스와 고체 플럭스의 차이점도 궁금하다재료 부분에서도 기초 클래스라 실수하다 수있다유리를 정말딱 맞다 보내다 가격에 비다 비약한 것같다ㅜㅠ또 액체 플럭승는자다 증발하다 뚜껑을 덮다 두다 하다 하다 플럭스푸다 용기를 뚝배기로 주신 점이 아쉽다뚜껑이 있다그릇이다 좋다것같다 1984
# 혼자 서도 영상만 보고따르다 좋다거같다좀더많다작품을 만들다 수있다더좋다것같다제 작품들에 너무나 만족하다 1985
# 수업을 진행하다 영상속에서 저와 같다수업 제품을 만들다 감잡다 꽤유용하다 1986
# 카메라보여주다 부분들이 조금 더 타이 트하게 들어가다 좋다해요  1993
# 낯설다 어렵다점말고는 재미있다 1995
# 접하다 어렵다수업을 들다 있다 좋다나다  1999
# 재밌다 어렵다 재밌다ㅠㅠ 2001
# 재료가 동일하다하다 같다방법만으로 진행하다 않다 점이 알차다 같다 2005
# 구성이 알차다만들다 방법이 다양하다 2007
# 자막 처리 반복되어다 천천히 보이다 내용 방향을 포인팅해주다 수업 이해도가 높다물론 연습과 노력은 저의 몫ㅎㅎㅎ 2010
# 자세하다만들다 모습을 보여주다 빨리 이해되다 재밌다 2024
# 어렵다않다 활 용도가 높다결과물을 만들다 낼 수있다생각 정리하다 딱 좋다수업인 것같다지방에 살다 못들다 북 클래스를 편하다집에서 들다 수있다너무나도 마음이 듭니다 이 수업듣다 정말자다 것같다 2030
# 캅틱 바인 딩 때문에 신청한 강의이다 스크랩 북처럼 강의의 다른 바인 딩 주제도 다 재미있다 유용하다 2032
# 만들다 과정을 차근차근알다 따라가다 어렵다않다 다양하다재료를 제공해주다 나만의 스타일로 제작해보다 것도 좋다 2033
# 차근차근 설명하다 주다 어렵다작업과 정도자다 따라가다 있다그만큼 성취도도 높다 2034
# 아직도 곡선자르다 기가 어렵다 재밌다생각보다 유리가 많이 튀어서 방에서는 못하다 같다수업을 몰다 보고만들다 보다 중인데 벌써 발에 작다유리 조각을 밟다 피가  2046
# 스태인드 글라스를 집에서 하다 너무 재밌다나중에 재료 추가로 살다 법도알다 너무 젛아 요 2047
# 자세하다설명좋다그런데자르다 붙이다 때 완성 품이 하다 화면에 나오다 좋다 같다 2048
# 생각보다 유리자르다 어렵다 재밌다ㅎㅎ 2057
# 처음부터 세다 하나 하나다 알다 수업따라가다 어렵다않다 혼자 서도만들다 수있다자다 설명 해주다 ㅎㅎ 2080
# 영상이 짧다 그렇다 지루하다않다  2085
# 처음엔 이해도안되다기계사 용법이나 프로그램 사용에 어려움이 많다조금씩 실력이 향상되다 느끼다 재미도 더 해가다 곧 토퍼 판매를 해도되다 같다기분이 들다 ㅋㅋㅋ 2096
# 어렵다 궁금하다부분을 하나 하나꼼꼼하다알다 너무 좋다 유용하다사이트 정보가 들다 좋다 2104
# 시은맘쌤이 상냥하다목소리로 해주다 친절하다설명이 귀에 쏙쏙박히다 어렵다않다 수업따라가다 수있다 좋다 2153
# 드개질새롭다기법을 알 수있다너무 좋다근데 세다 설명이 조금부족하다영상을 많이 돌리다 보다 적이 있다 2154
# 1차 태와 달리 화면에 어떤부분을 진행하다 나타나다 있다화면만 보고하다 되어다 정말편하다뜨다 질을 하다 역시시은맘짱이다괜히 1등하는게아니다 2160
# 초보인 저에게 딱이다앞으로도 잘알다 바라다  2181
# 어렵다부분들차근차근자다 설명해주다 어렵다않다 뜨다 있다 2192
# 배우다 싶다 배우다 있다 좋다것같다 2195
# 각 강의가 짧다 좋다집중 도가 좋다수업 노트보다 진행하다 좋다 2212
# 디테일한 설명이 초보자들에게 너무 좋다 궁금하다만들다 후 뒷정리라 던지다 판매 및 선물하다 시KC검증을 하다 하다 하다 방법이렇다알고 싶다  2220
# 캔들에 대한가다 초 지식이 없다기본부터 설명해주다 많다도움이 되어다  2226
# 채다 터 하나 하나 다른 왁스 다른 유형의 캔들을 접하다 수있다흥미가 떨어지다 새가 없다 같다 2229
# 캔들만들다 시간가다 모르다 능ㅎ더 심화과 정도나오다 또 수강하다  2231
# 처음이라 어렵다하지만계속 반복하다 수강하다 충분하다따르다 하다 수있다 좋다 2234
# 반복되다 스킬을 자주보여주다 도안에 맞다 포인트를 찌다 느낌이에요 저한텐아직 어렵다손을 어떻다놓다 하다 좀 헤깔리다 폴디드 조인 마지막 조인을 영상으로 볼 수있다 좋다 2239
# 초보여 도 다른 작품에 도전해보다 흥미가 생기다 스킬에 대해서 자다 설명해주다 것같다수밍님의 유튜브도 함께 보다 더좋다것같다 2240
# 요령이 아직 없다 그렇다많이 서툴다하나 하나만들어지다 것을 보다 신기하다 2241
# 하나씩차근차근알다 좋다그런데뒤로 갈다 수록 미션 수행하다 적어지다 느낌이라 미션 수행이 더늘어나다 좋다선생님이 만들다 완성 품을 사진으로 게시하다 주시면 좀 더좋다참고 사항이 되다 수있다 같다 2245
# 초보자가 따르다 하다 조금어렵다부분들도 있다천천히 설명해주다 자다 따라가다 있다 2248
# 어렵다기도하지만피드백도 자다 주시고 점점 흥미를 가지고 있다항상 감사드리다  2249
# 처음해보다 클래스인데 도 설명도 자다 해주시고 댓글 답변도 자다 해주시고 한강의씩클리어하다 때마다 보람있다 2253
# 조금 더쉬다 설명이 되어다 좋다실이 얇다실인데 겹치다 줄이다 때 다각도에서 보이다  2259
# 이제 모양도 예쁘다자다 여유가 생기다 같다기초부터 차근차근재미있다 2260
# 쉬다 설명이 되어다 좋다하지만조금 더자세하다설명이 되어다 있다더좋다것같다 2263
# 생가보다 어렵다구간도 있다손이 자다 못따라가다 경우도 있다너무 재미있다수강하다 잠기다 나머지 수업이 기다려지다  2266
# 천천히 상세히 설명해주다 동영상으로 배우다 어렵다않다 같다 2273
# 점점어렵다ㅎ너무 멋있다작품이 되다 기분이 좋다ㅎ 2276
# 예쁘다만들다 자세하다설명해주다  2280
# 어렵다넘다 재밌다하나 하나만들다 너무 뿌듯하다 2284
# 피드백 바로 주시고 첨 해보다 동영상 보고되다 신기하다 2291
# 쉬다 잘알다 금방 완성하다 한번하다 아쉽다풀다 달다 중이에요 ㅎ 2303
# 어렵다않다 자다 설명해주다 좋다생각보다 한개만들다 오래 걸리다 시간태우다 너무 좋다 2304
# 처음엔 어렵다보여서 이걸어떻다따르다 걱정하다 천천히 따라서만들다 보다 어느새다작품하나가 만들어지다  2307
# 매듭묶다 힘 조절이 어렵다웠어요 ㅜ그래도 어떻게든 ㅋ완성ㅋ뿌듯하다  2308
# 처음엔 하다 수있다 두렵다막상해보다 자다 하다 수있다 2313
# 차근차근 설명도 자다 해주시고 여러가지 팁이나 유용하다소개도 좋다 어렵다않다 자다 따르다 하다  2314
# 기계가 없다무슨말인지 모르다 있다고해도 실질적으로 글씨를 컷팅하다 과정이 아니다도움이 되다 않다 함 2317
# 한복을 직접만들다 보다 점과 처음 재봉틀을 사용하다 사람들도 접근하다 수있다점이 좋았습닏ㄱ 2325
# 설명을 차분하다잘해주다 그런데너무 차분하다잠이 오다 집중력이 약하다 재밌다다음 날 다음 날 계속보다 되다  2326
# 좋다화질 상세한 설명이 좋다근데 너무 국어 책읽다 듯한 발음만 좀아쉽다이해안되다계속되돌리다 감기하다 보다 괜찮다 2329
# 선생님 목소리가 듣기편하다설명을 잘해주다 같다 2358
# 재료를 준비하다 필요가 없다맘이 한결가볍다시간 내기어렵다분들도 기간이 넉넉하다시간 날때 틈틈이하다 좋다 2371
# 초심자가 힘들다하다 부분들을 배려하고 만들다 주신게 눈에 보여서 차다 좋다강의 중간 중간에 띠부님의 경험을 섞다 알다 들이다 따라가다 도움이 많이 되다 강의를 훨씬 입체적이고 풍부하다만들다 같다ㅎㅎ좋다클래스이다ㅎㅎ 2377
# 어렵다않다 꼼꼼하다수업이 진행되다 미션을 완료하고 넘어가다 시스템이 되어다 있다 확실하다알고 넘어가다 있다 좋다 2385
# 차근차근 숙지하다 해주다 어렵다자다 따라가다 하다  2387
# 펠팅하다 시간 동안같이 펠팅해주다 어느정도가 적당하다가늠하다 있다 2392
# 옆에서 같이 만들다 수업하다 느낌적느낌이 들다  2397
# 나무를 물속에 오다 담가두다 안되다 2407
# 모든부분에서 좋다배움으로 더다양하다만들다  2412
# 다 좋다다만 날을 연마나 스트로 핑은 어느주기로 해주다 좋다 2413
# 강의만이 아니다밑에 글로 정리하다 것이 강의를 두번듣다 돌리다 보지않다 좋다것같다 2419
# 마지막안보이다 과정까지 다 알다 좋다 2421
# 4가지의 다른 비누를 만들다 보다 응용하다 다르다만들다 수있다것같다 2427
# 비누 완성하다 여러가지 과정을 거치다 영상을 두세번 보고 머리 속으로 익히다 빠지다 영상으로 이해는 잘되어다 혼자하다 영상없이 안되다 2431
# 공방에서 원데이 클래스하다 영상보다 하나 하나따르다 야하다속도가 좀느리다하지만집에서 혼자따르다 괜찮다것같다 2433
# 방법이 귀찮다 단순하다 2445
# 까다롭다작업이지만 이시국엔 집에서 하루 종일지루하다않다 보내다 수있다해주다  2461
# 수업 노트가 굉장하다구체적이어서 만들다 크다 도움이 되어다 초보자 눈높이에 맞추다 굉장하다쉬다 알다 수강 후 영상없이 스스로 캔들을 만들다 문제없다것같다감사하다 작가님 2465
# 먼저 보고하다 쭉보다 차근차근쉬다 알다 누구나 따르다 하다 수있다 같다조색이나 더더 더더 다른 몰드로 도 또 클래스열다 오오오오오오수 제몰드는 만들기 더어렵다데 일리소 이왁스도 쓰다 온도맞추다 어렵다ㅣ 2467
# 캔들 처음만들다 보다 너무 재밌다하루만에 반넘다 들다 ㅋㅋㅋ 2468
# 강사님말투가 차분하다영상 보기편하다 2480
# 어렵다않다 누구나 따르다 하다 있다 2489
# 어렵다않다 술술넘어가다 넘다 좋다 2494
# 너무 설명도 잘해주다 쉬다 재밌다만들다 있다 좋다 2495
# 하나 하나하다 방법을 보다 있다 2507
# 비누 만들기는 첫도전이라 어렵다생각하다 천천히 자세하다설명을 해주시니 쉬다 따르다 하다 수있다 같다주의 사항도 세심하다 체크해주다 안심이 되다 내피부 타입에 맞다 비누를 내가 디자인하다 만들다 생각하다 신나요 2513
# 강의내용이 귀에 쏙쏙들어오다 채다 터마다 중복되다 부분도 있다강의 내용에 중복 부분까지 꼬박꼬박다 기재해주다 들다 때마다 반복 학습도 자다 되어다 무엇보다 천천히 속도를 맞추다 강의해주다 너무 좋다 2521
# 꼼꼼하다쉬다 강의하다 차다 어렵다일인데 워낙 전문갈다 그렇다 시원시원하다알려지다 좋다비누도 따라서자다 만들다 있다 2523
# 꼼꼼하다체계적인 수업 강의에요 다만 다른 오일들에 대해 서도 설명이 있다더좋다것같다 2525
# 트레이스 부분이 조금어렵다디만 열심히 보고있다 2531
# 꼼꼼하다알다 따라가다 어렵다않다  2542
# 달 표현하는 방법이 신기하다 2565
# 앞으로의 수업이 기대되게 만들다 채다 터1이다  2574
# 재료 준비 과정이 너무 오래 걸리다 따르다 하다 엄두가 안나요 그만큼 시간도 없다그냥 강의 보 는걸로 만족 중이에여 ㅜㅜ 2583
# 밉다뜰리에  에서알다 방법으로 하다 뭔가이상하다결과물을 올리다 빠르다 좋다피드백을 줄다 그래서 더욱 잘만들수있다만들다  2585
# 조 근 조 근설명해주다 좋다근데 마지막으로 앙금만들다 때맨 마지막불다 대 한언급이 없다 헷갈리다 2586
# 미리 영상만 보다 재료 준비하다 빨리 만들다  2590
# 피드백잘해주다 달다 분들궁금증읽다 보다 답글이 도움이 되다  2593
# 수업을 보고듣다 보다 화과자의 매력에 점점빠져들다 없다 2594
# 상세하다 짚다 강의해주다 만들기어렵다않다  2602
# 속도가 빠르다않다 이해하다 좋다 2605
# 아직 재료를 받다 알다 디만 예습중 2624
# 쭘언니는 목소리 자체가 인강에 적합하다 같다너무 느리다 빠르다않다 설명이 굿 2626
# 캔들만들다 과정이 카메라에 더자다 보이다 좋다반짝이다 넣다 장면은 거의 보이지가 않다 이해하다 하다 차다 걸리다 무엇보다 재료가 초를 딱 하나씩만 만들다 정도로 보내다 이 점이 좀그렇다 2639
# 재밌다ㅎㅎㅎ재료를 더 사서해보다 싶다  2641
# 뜨다 질 온라인 수업을 처음들다 보다 과연 동영상을 보다 자다 따라가다 수있다하다 생각을 하다 저만의 기다 바이브 리 선생님께서 너무나 자다 가르치다 한번도 해메지 않다 자다 따르다 하다 수있다요 바이브 리 샘의 수업을 신청하고 한참 뒤에 선생님의 강의 셋을 같이 들다 수있다자유 이용권이 생기다 알게 되다 안타깝다선생님의 다른 클래스도 듣다 싶다 생각이 이번 클래스를 들다 생기다 일단 이번 수업은 완강을 하다 잠시 다른 수업 하나듣다 자유 이용권 신청하다 하다 중복되다 수업과 재료는 다른 인형만들다 때 사용하다 되다 요 바이브 리샘너무나 즐겁다인형 만들기에 집중하다 수업이다 감사하다 여러가지 팁알다  2646
# 어렵다부분도 엄청 쉬다 알다 너무 좋다 귀엽다인형들을 만나다 좋다 2647
# 처음 클래스 강의를 들다 보다 정말 체계적다 같다작가님들이다 영상도 자다 만들다 주다 클래스의 세심한 부분들이 불편하다점없이 수정도 많다고민도 많이 하다 싶다 ㅎㅎ 2649
# 꾸준하다들다 수있다한번듣다 분량이 적당하다 2656
# 혼자 독학으로 해보다 배우니까 이해도잘되다 확실하다방법을 알다 같다 2668
# 왁스를 녹여서 굳히다 내용의 연속인데 같다내용의 수업내용이그저 모양과 컬러만 드를 뿐인데 여러채다 터로 돼다  2670
# 선생님 말투와 목소리도 귀엽다귀에 쏙쏙들어오다  2674
# 어렵다않다 차근차근자다 설명해주다 일단 여기까지는 난이도도 썩어렵다않다 것같다 2681
# 가르다 처줄다 때 조금 빍은 색상을 사용하다 좀더 보기편하다 같다 2687
# 작품을 만들다 다른 작품에 적용하다 수있다부분이 많다 굉장하다 유익하다것같다습나다  2689
# 원단 세탁 후말리다 시간이 힘드다한번에 쓕 완성되다 아니다ㅎㅎ세탁 후 건조 시간기다리다 다음 작품을 하다 되다 이 또한 매력있다ㅎㅎ 2696
# 너무 귀엽다ㅠㅠㅠㅠ그래도 앞에서 브로치만들다 보다 고양이 얼굴이 전보다 귀엽다만족근데 글루건이 없다접착제 사용하다 떨어지다 좌불안하다 2699
# 아기자기하다 섬세하다설명과 시간가다 모르다 신족한 전개 배움의 과정이 너무 재다  2700
# 동영상으로 차근차근알다 쉬다 사진으로 설명도 따로 되어다 천천히 따르다 좋다것같다 2705
# 모르다 부분 하나 하나너무 자다 설명해주다 ㅎㅎ 2711
# 질문에 대한 강사님의 빠르다피드백이 너무 만족스럽다 2714
# 까만색 실이 바늘의 움직임을 보기어렵다 아쉽다 만족하다 2717
# 반복적인 부분은 빠르다감다 도영상보기가 지루하다않다 좋다 2730
# 고양이 짱 귀욤 더 연습 하연서 귀엽다만들다 욤 2739
#
# ----------------------------긍정에 대한 감정분석 결과-------------------------------------
# 전체 데이터 수: 2743
# 정확히 분류된 댓글: 2126
# 잘못 분류된 댓글: 518
# 분류 정확도: 80.0%

# %% [markdown]
# ## 부정부분 감성분석

# %%
import numpy as np
import pandas as pd


def neg_counter(data):
    negative_n = 0
    neg_front_search = ['보이지', '아깝다', '충분하다않다', '더자세하다', '더좋다', '아쉽다',
                        '쓸데없다', '느리다', '빠르다', '면 좋다', '좋다것같다', '안되다',
                        '헤메다', ' 좋다듯하다', '부족하다', '더들어가다', '어렵다', '비싸', '빠르다것같다', '자주나가다', '그만',
                        '너무늦다', '부족하다', '부분', '당황', '안타깝다']

    neg_back_search = ['다만', '없다', '그런데', '충분하다않다', '조금 더', '근데', '쓸데없다', '솔직', '너무짧다']

    neg_binary_search = ['실망', '부족', '버거운', '것같다', '좋다것같다', '단점', '너무짧다', '어렵다',
                         '때문에', '보완', '섬세', '너무많다', '무리', '않다', '기다']

    # 실망 댓글에서 분류하기 위한 3가지 카테고리 => 영상 품질 실망, 컨텐츠 내용 실망, 재료 관련 실망 카테고리
    neg_video_accord = ['버퍼링', '화질', '속도', '빠르다', '짧다', '보이지않다', '놓치다', '오류', '어둡다', '어두워지다',
                        '안들리다', '보이지', '안보이', '영상', '진도', '뚝뚝', '버퍼링', '스킵', '모양', '안들리다', '세밀',
                        '사이트', '과정', '하단', '확대', '보기', '감기', '초점', '안보이', '화질', '목소리', '평가',
                        '어두워지다', '클로즈업', '안보', '가까이', '화면', '모션', '자막', '오류', '각도']

    neg_content_accord = ['힘들다', '어렵다', '구체적', '헷갈', '반복되다', '환기', '진행', '해소가', '뒤죽박죽',
                          '안나오다', '각인', '장식', '단어', '돈', '작품', '답', '답장', '설명', '방법', '듣기', '교재', '이해', '비용', '힘들다',
                          '어렵다', '깊이', '용이', '초보자', '피드백', '수업', '빠르다', '속도', '시간', '내용', '만들기', '답변', '정보', '진행',
                          '기법', '너무짧다', '강의', '반복되다', '예시', '처음', '앞']

    neg_material_accord = ['촌스럽다', '얇다', '상품', '안오다', '구슬', '준비물', '분량',
                           '패키지', '안오다', '제품', '구성', '주문', '재료', '프린터']

    neg_weight_word = ['다만', '그런데', '충분하다않다', '조금 더', '근데', '쓸데없다', '어렵다', '안타깝다', '좋다것같다',
                       '아쉽다', '더필요하다', '조금불편하다']

    neg_word_list_zip = [neg_front_search, neg_back_search, neg_binary_search,
                         neg_video_accord, neg_content_accord, neg_material_accord]

    for neg_word_list in neg_word_list_zip:
        for neg_word in neg_word_list:
            if neg_word in data:
                if neg_word in neg_weight_word:
                    negative_n += 6
                else:
                    negative_n += 1

    return negative_n


def pos_counter(data):
    positive_n = 0
    pos_front_search = ['빠르다', '감사', '알차다', '만족도', '성취감', '따르다', '구체적으로', '쉬다', '아주',
                        '자세하다', '알게', '좋다', '배우다', '꼼꼼하다', '쉽다', '피드백을', '가르치다', '따르다',
                        '뿌듯', '좋다']

    pos_back_search = ['빠르다', '감사', '알차다', '만족도', '성취감', '따르다', '구체적으로', '쉬다', '아주',
                       '자세하다', '알게', '좋다', '배우다', '꼼꼼하다', '쉽다', '피드백을', '가르치다', '따르다', '최고']

    # 긍정 댓글에서 분류하기 위한 2가지 카테고리 => 영상 설명, 결과물 만족 2가지 카테고리

    pos_content_accord = ['댓글', '답변', '친절', '정보', '팁', '성취', '설명', '피드백', '꼼꼼', '차분', '자세히', '차근차근',
                          '디테일', '기법', '상세', '강의', '이해', '자세', '쉽다', '다양', '실용', '알차다', '구체',
                          '노하우', '알차다']

    pos_product_accord = ['결과물', '디자인', '스타일', '퀄리티', '작품']

    pos_weight_word = ['최고', '너무 좋다', '뿌듯', '꼼꼼']

    pos_word_list_zip = [pos_front_search, pos_back_search, pos_content_accord, pos_product_accord]
    for pos_word_list in pos_word_list_zip:
        for pos_word in pos_word_list:
            if pos_word in data:
                if pos_word in pos_weight_word:
                    positive_n += 5
                else:
                    positive_n += 1

    return positive_n


def return_sentiment(data, weight_score):
    pos_score = pos_counter(data)
    neg_score = neg_counter(data)
    try:
        sentiment_percent = np.round((pos_score / (neg_score + pos_score)) * 100, 2)
    except:
        return 0, 0, 0, 'not enough data'

    if sentiment_percent > weight_score:
        return pos_score, neg_score, sentiment_percent, 'good'
    else:
        return pos_score, neg_score, sentiment_percent, 'sorry'


reviewList = pd.read_excel('./dataset/stemming_sorry_review.xlsx', engine='openpyxl')
reviewList.drop(reviewList.loc[reviewList.review.isna()].index, axis=0, inplace=True)
reviewList.reset_index(inplace=True)
reviewList.drop('index', axis=1, inplace=True)

data_n = 0
correct_n = 0
fail_n = 0
not_correct_n = 0


print('<제대로 분석이 된 댓글들>\n')
for i in range(len(reviewList)):
    review = reviewList.iloc[i, 1]
    pos_score, neg_score, sent_per, sentiment = return_sentiment(review, 48)
    data_n += 1
    if sentiment == 'sorry':
        correct_n += 1


    elif sentiment == 'not enough data':
        not_correct_n += 1
        continue
    else:
        fail_n += 1
        print(review, i)

print('\n----------------------------긍정에 대한 감정분석 결과-------------------------------------')
print('전체 데이터 수: {}\n정확히 분류된 댓글: {}\n잘못 분류된 댓글: {}\n분류 정확도: {}%'.format(data_n, correct_n, fail_n, np.round(
    100 * correct_n / (correct_n + fail_n))))

# pos_score, neg_score, sent_per, sentiment =\
#     return_sentiment('작가님의 강의는 꼼꼼하다차다 좋다다른 클래스와 다르다준비물을 구매하다 않다 똑같이만들기는 쉬다 않다 . 사이즈도 안나오다 있다, 패턴만 따로구매도 안되다 하니 좀아쉽다. ㅠㅠ', 49)
# print(pos_score, neg_score, sent_per, sentiment)
# Out:
# <제대로 분석이 된 댓글들>
#
# 입문 용으로 설명을 쉬다 해주다 좋다하지만마을지 기분이 미숙한 부분이 많이보여서 아쉽다 32
# 빠지다 제품 때문에 시간이 걸리다 기도하다 다른분들보내다 땐 체크하다 자다 보내다 정말완벽하다거예 요너무재밌다 쉽다강의이다  38
# 열심히해주다 중간 중간 좀 더 상세히설명하다 주다 좋다텐데아쉽다 40
# 친절하다 좋다속도가 조금빨르다요ㅠㅠ 48
# 아주자세하다알다 것은 좋다부분이다하지만처음 주신 장비들중에 날이 안서다 있다구두 칼 일지 비베다 펀치 등은 보완하다 하다  61
# 날대다 잇다 하다 때 좀 더자세하다설명해주다 좀 더좋다거같다요 하나 작품이 끝나다 때 좀엉성하다부분이 생기다 조금아쉽다웟어요 ㅜ그래도처음 작품을 제 손으로 만들다 되다 너무좋다일끝나다 구라 타다 공예하다 게 지금은 취미가 됫어요 만들다 자다 때가 제일뿌듯하다 65
# 처음 강의에서 하라는 대로하다 갑자기 다시 처음으로 가다 하다 차다 맷어요 ㅠㅠㅠ처음부터 31로보이다 주심이 좋다거같다ㅠㅠ 66
# 전반적으로 만족하다진도가 너무느리다비슷비슷하다강의가 반복되다 느낌이에요 좀 더 강의 내용이 다양하다 좋다평소궁금하다것들을 배우다 수있다 좋다 73
# 알아듣다 쉽다설명과 다소 무난하다 따르다 하다 수있다작품들인 것같다다만바라다 게있다응용 법이 좀 더있다 좋다 80
# 젛아요 피드백 좀그만하다싶다 용 클래스는 너무좋다이게 너무별로에요 너무 너무ㅜㅜ 88
# 꼼꼼하다설명을 잘하다 주시기는 하나자세하다보아야 하다 부분이 자다 보이지않다 점이 조금아쉽다 103
# 동영상이 좀 뒤죽박죽인 느낌ㅜㅜㅜ저만그렇다모르다 일단 동영상하다 번 쭉다보다 뒤에 다시 보기로 시작하다 게좋다듯 105
# 자세하다설명해주다 따르다 하다 쉽다개인 스케치까지 같이보다 줄알다 그 부분은 완강 후알다 작업하다 거라 아쉽다그 목적이 가장크다 강좌 타이틀이 조금 과장되다 듯하다  108
# 차분하다설명이 차다 좋다건의 사항있다플레이하다 작업따르다 위해멈추다 영상 한가운데붉다은색 화살표가 나오다 요 참고하다 화면이 가려지다 표현법을 자세하다볼 때아쉽다구 요이렇다건 클래스101에 건의하다  109
# 부가적으로 구매하다 하다 재료들이 너무많다해요 ㅜ제면 기 핫 플레이 트 하얀색 등 등 재료에 대한 설명이 하다 번 더있다 좋다 112
# 화질이 너무안좋다꽃붙이다 때정확하다 어떻다방향으로 하다 알아보다 힘들다색 조색도 너무겉핡기만 배우다 거같다 114
# 자세하다디테일한 설명으로 어려움은 없다초보가 따르다 하다 속도가 빠르다느낌 116
# 좋다초보가 따르다 하다 영상이 빨르다그게너무아쉽다 118
# 설명이 부족하다듯하지만필수 설명을 다해주시는 거같다 자세하다보여주다 좋다 124
# 플럭스 물희다석하다 때 비율 유리와 거울 접합 부분은 오다 유리와 유리 부분보다 사이 공간이 더많다건지다 어느상황에서 그게가능하다어느상황에선 그 방법을 추천하다 주지않다 좀 더 설명이 자세하다 좋다 130
# 너무좋다혹시 윗 단계 강좌는 하다 않다 요 지방에 살다 배우다 데 한계가 느껴지다 ㅜ 132
# 디테일한 설명없이선생님 혼자 작업하다 느낌이다ㅠ 136
# 차근차근 설명해주다 부분이 좋다매듭은 조금 더천천히해주다 자세하다노트가 있다 좋다 146
# 소리가 다른 수강에 비다 작다편이지만 조목조목자다 짚다 설명해주다  154
# 목소리자다 안들리다 거빼다 친절하다자다 알다 좋다 155
# 좋다 좋다생각하다 막강들다 가깝다이 가격에 이 퀄리티 의문이 네 욤 차라리 강의 비만큼 귀걸이를 살다 게 이 쁘고 나다 끄다 같다 158
# 여러 종류의 귀걸이 제작 방법을 알 수있다점에서 좋다조금아쉽다점은 세밀한 작업하다 부분은 카메라 줌을 이용하다 더 가까이에서 보여주다 좀 더쉬다 보고따르다 하다 수있다것같다 160
# 설명이 자세하다 좋다하지만재료가 두개나 잘못오다 ㅠㅠ다시보내다 재료 체크만 자다 해주다 강의는 완전 만족이다 169
# 친절하다 자세하다설명해주다 좋다가끔 작업하다 무의식 중에 카메라 밖으로 손이 나가시면 놓치다 조금초조하다때도 있다ㅎㅎ 170
# 강의1개마다 시간을 늘리다 좋다거같다요너무뚝뚝끊기다  178
# 귀걸이를 만들다 보다 게좋다 181
# 펜치가 조금불편하다거빼다 설명과 재료들다좋다 182
# 선생님이 자다 가르치다 넘다 좋다그치다 기본은 알고 잇다 터라 ㅠㅠ좀아쉽다 183
# 라 타다 왕초보도 따르다 자다 만들다 수있다차근차근 설명해주다 부분이 좋다용 살짝아쉽다점은 두 줄을 하다 줄로 줄이다 부분이나 첫 줄을 스탠드에 감다 엮기 시작하다 부분은 다같다색깔이다 보다 어느줄을 엮어야 하다 자다 안 보이고 헷갈리다하다 20번은돌리다 보다 거같다요ㅠ 184
# 화면이 촛점이 자다 안맞다 때가 있다하지만그래도설명을 자세하다해주다 이해가 쉬다  192
# 다좋다배경음악이 좀 다채로웠으면 좋다끝판쯤되다 약간지겹다노래가  194
# 고리 이동에 대한 설명이 좀 더자세하다 좋다ㅠ그리고클래스101버퍼링너무심해요 ㅠㅠ 195
# 헷갈리다데 속도가 너무빨르다요느리다재생하다 버벅거려서 따르다 하다 못하다  196
# 영상을 보다 하다 옆에서 가르치다 게아니다체인의 방향이나 볼 실의 위치 조인하다 것들의 자세하다영상이 없다모양이 맞다 되다 확인이 안되다  197
# 천천히여러 번보여주다 좋다채다 터 완료하고 완성되다 부분 사진을 보여주다 좋다거같다 199
# 천천히나가다 건좋다몰드에 점차 비누 액을 붓다 나가다 때 기울기를 어찌하다 쫌 더자세하다나오다 좋다처음에 뚜껑 위에 올려놓다 붓다가 어느순간 뚜껑닫다 땐빨다 빨다 지다 있다고 부분이 자다 이해가 안돼다 거말고는 좋다 218
# 설명이 미흡하다 225
# 가격에 비다 솔직하다가르치다 주다 게 별로없다 226
# 좋다가짓수가 좀적다  227
# 친절하다설명감사하다 명화 캔들 수업 때찍다 모습이 가다 자다 보이지않다 게 조금불편하다 좋다 249
# 영상 작업은 무조건 전문 팀이 하다 좋다앵글이 보기불편하다구도네요 같다강의 더라도 영상의 퀄리티 차이로 인하다수강의 질 차이가 이 주크다  250
# 설명이 자세하다자다 되어다 있다생각하다 하다 보다 좀 더 부가 설명이 있다 좋다생각이 들다 다양하다활용 방법이라든지 요 253
# 영상이 건마다 더 길 고자세하다 좋다거같다 254
# 넘다 빨리지나가다 ㅜㅜ그래서10초되다 감기를 하다 듣다 재생 오류가 나서다 계속 앱을 끄다 다켜다 해요 작가님은 좋다앱이 별로에요  258
# 발음이 조금 신경쓰이다 기다 하지만쉬다 가르치다 주다  260
# 강의를 하나 하나따르다 하다 게재밌다아그리고레진을 하다 때실패하다거에 대한 대처 방법도 정리하다 나오다 좋다 285
# 대체로좋다제가 자다 못하다 똑같이하다 불구하고 조금의 차이다 있다거같다요 다른 분들도 다르다나오다 점에 대해서다 자세하다피드백은 듣다 못하다 점이 많이아쉽다 290
# 너무기초에 요이렇다날 케이크너무나유명하다곳이라서 다른 강의와는 특별하다차이가 있다끄다 기 대하고 등록하다 이 정도 기초를 가르다 키는 줄모르다 ㅠ 293
# 수업재밌다 좋다다만 커리큘럼이 좀 더많다하다 아쉬움이 있다강의 하나씩의 길이가 짧다느낌이 있다다른 강의도 듣다 있다그림 수업이라 그렇다거기다 하나채다 터 안에 4개씩작품이 나오다 하나당강의 길이가 30분내외라 완강하고 나다 작품 수가많다 뿌듯하다이 수업은 처음 수강신청하다 때보다 오다 사진들속 작품을 배우다 수있다건가하다 기대하다바스 붐 모양 내기의 방법이 기대에 못미치다수업 처음기다리다 보다 사진 속 바스 붐은 아직도만들다 못하다 요배우다 것에 대한 만족도에 비다 커리큘럼에 대한 만족도는 조금떨어지다 편입 니다 ㅠ 305
# 떡에 대한 설명보다 포장에 대한 설명에 치우치다 느끼다 ㅠㅠ 307
# 달의 모양을 자세하다 어떻다잡다 되다 설명이 더필요하다 좋다ㅠㅠ 308
# 포장 법 좀 더ㅜ다양하다추가해주다  312
# 강의가 꼼꼼하다진행되어다 따르다 하다 좋다하지만미션 수행한 후 코멘트를 받다 보다 적이 아직없다다른 클래스101수업들에 비다 그 부분이 아쉽다 313
# 사이트가 느리다내용에 기준 선이 더명확하다 좋다다퍼주는 남자 강의처럼  316
# 좋다좀 더 화면에서 이렇게하다 인물 중심으로 보이다 거고이렇게화면이 돼다 배경 중심이라는 것을 보여주다 좋다거같다 323
# 용어나 높이다 다낮추다 다얕다 깊다 같다말과 숫자랑 연관지다 않다 요 직접적인 설명이다 좋다 326
# 꿀팁이 별로없다느낌ㅠㅠ 334
# 실제적인 예를 확인하다 수있다 좋다피드백이 조금늦다 아쉽다 336
# 수업 내용이 재밌다 자세하다조색 예시가 더들어가다 좋다 341
# 쉬다 간편하다 좋다.. 아쉬움이 많다하다 요한 글 도안을 준비하다 가다 노력 대비 안이쁘다비추다 하다 가지고 있다도 안으로 하다 이 쁘네요 손님이 하다 번에 오다 정신없다보여서 그렇다설명도 부족하다부분이 있다거같이느껴지다 색 추가하고 남다 네온이 있다추가로 가능하다꼭.. 자르다 말다 ㅎㅎ전 설명을 못듣다 제맘대로자르다 그게 끝이  라고하다 ㅎㅎㅎ허허...  343
# 작가님이 설명을 쉬다 해주다 쉬다 따르다 하다 수있다우드 트 레이 완성하다 넘다 뿌듯하다. 만들다 방법을 차례 대로 정리한 설명서 가다 있다더좋다듯하다  345
# 작가님의 강의는 꼼꼼하다차다 좋다다른 클래스와 다르다준비물을 구매하다 않다 똑같이만들기는 쉬다 않다 . 사이즈도 안나오다 있다, 패턴만 따로구매도 안되다 하니 좀아쉽다. ㅠㅠ 347
# 수강자다 들다 램프랑 공구 등 대부분갖다 있다따로주문하다 만들다 아쉽다건 동백꽃 몰드는 작가님스토어에도 팔지를 않다 ... 검색의 한계를 느끼다 다른 것들만 따르다 만들다 그리다 톡, 목걸이늘다 선물주다 책갈피만 남아서 사진이 하다 장뿐이다ㅠ쉐이커는 제가 2액형비율을 잘못한 건지다 자다 못섞다 건지다 망하다이틀째굳다않다 다시 도전하고 모르다 겠다 마니님유튭보다 천천히만들다 보렵니 다레진망하다경우 처리 방법에 대해자세하다알고 싶다 혹시라도 제 후기를 보다 수강이나 유튭에 올려주다 하다 곰손 수강생의 작다바램을 담다 후기마치다  350
# 뭐... 20만원이나주다 들다 만큼 퀄리티그렇다거 눈아니다요아끼다 들다 려고하다 까먹다 ... 제 잘못.. 그래서수강다못들다 벌써다끝나다 버리다 아예... 제20만원은하늘로 날아가다 ... 하... 하...  351
#
# ----------------------------긍정에 대한 감정분석 결과-------------------------------------
# 전체 데이터 수: 356
# 정확히 분류된 댓글: 283
# 잘못 분류된 댓글: 69
# 분류 정확도: 80.0%

# %% [markdown]
# ## test dataset을 이용한 감성모델 정확도 검증

# %%
def stemming(review):
    from konlpy.tag import Okt
    okt = Okt()
    
    malist5 = okt.pos(review, norm=False, stem=True)    
    comment = ''
    last = ''
    for pos in malist5:
        if pos[1] in ['Verb','Punctuation','Adverb']:
          comment = comment + pos[0] + ' '
        elif last == pos[1]:
          comment = comment + ' ' + pos[0]
        elif pos[1] == 'Josa':
          comment = comment + pos[0] + ' '
        else:
          comment = comment + pos[0]
        last = pos[1]
    return comment

review_list = ['정말 너무너무 만족스러운 취미에요. 재미도 있고 결과물도 진짜 예쁘고 마음에 들어요. 전혀 돈이 아깝지 않아요!!!! 수국 무드등도 얼른 만들어봐야 겠어요♡',
              '갈색시약병이 공지 못본건지 바뀐걸 몰라서 그냥 유리병이 왔네요~ 갈색병 선물로 드릴려 했는데 실망했습니다 바뀐점을 미리 공지하시고 사진도 교체하시면 좋겠네요 기분좋다가 재료받고 구성품이 바뀌어 기분안좋았습니다',
              '울적한 기분을 캔들로 힐링했다~~ 정말 행복하고 뿌듯하고 성취감 뿜뿜!!! 적극적으로 추천합니당^^',
              '저울이 먹통이여서 그다음날 연락하고 재출고 해주시기로하셨습니다. 하지만 저희동네는 cj가 밤10시에온다는거~일단 그점이아쉽구요 주말끼고도 꽤 오래 기다렸던 터라 일단저울은 다이소서 사서했어요 온도계는좀아쉽습니다 온도가 천천히올라가서 올려놓고 기다려야해서 불편해요 향료양도 좀아쉽습니다 왁스는 다만들고 여유되더라고요 근데향료가 여유롭지않아요 제가만들다가 왁스타블렛을 실수로 엎어서 저는향료 모자랐..ㅜ 그거빼곤 만족입니다 저는 버블캔들몰드 다닦고했는데 왜 매끄럽게안나왔을까요 ㅜㅜ 추가향료사서 더만들어볼려고요',
              '마지막까지 완성했어요 ! 거울은 염색시켜서 했어요 !! 라탄은 충분히 물에 불려야 더 예쁘게 만들어지는것같아요 ! 만들고나니 너무 뿌듯하고 예쁘네욤 ! 단순 반복이라 처음에 잘 해두면 끝부분까지는 금방 할것같네요 ~~',
              '프랑스자수 좋아하는데요 채색자수는 처음보는거라 바로 질렀어요 넓은 면적을 물감을 칠하다니 와 진짜 기발하네요 그래서 너무 재밌어요 그림이랑 자수 둘다 배울 수 있어 뭔가 가성비 높은 취미라고 해야할까 암튼 재밌게 하고 있어요!',
              '정규클래스 처음인데 가격도무난하고 좋네요 3개월치가 이정도면.. 키트는 벌써 받았는데 이번꺼 패키지가 풍성해서 좋아요 ㅎㅎ 다음에는 새로운거 해보고싶어요',
              '라탄 엄청 재미있어요 설명도 친절하시구요 이제 제 스스로 더만들것을 찾아본답니다',
              '체험단 당첨으로 만들게 됐는데 사정이 생겨서 이제야 다 만들고 글을 써요! 처음에는 손도 아프고 익숙치않아서 어려웠는데, 하나씩 만들어 갈때마다 손재주가 느는게 보였어요 ! 강의에서도 이해하기쉽게 잘 설명해주셔서 이해하기 쉬웠고, 강의를 다시 볼려보거나 필요할때 볼수있다는게 가장 큰 장점인거같아요. 라탄도 충분한 양을 넣어주셔서 만들고 싶은걸 또 만들수있을거같아요! 전혀 돈 아깝지 않은 클래스같습니다! 덕분에 취미생활이 하나 더 늘었어요~ 감사합니다~',
              '살짝 살짝 헷갈리는 부분이 있긴 하지만 재밌게 만들었어요',
              '좋은 취미를 얻었어요♡ 입문과정으로 듣기좋아요 마무리할 때 살짝 헷갈린 감이 있어서 좀 더 클로즈업해주시면 좋을 것같아요 아직도 확실하게 한 건가 제 작품에 좀 미심쩍은 감이 있어요 ㅠㅠ 이 강좌보고 서점에 가 라탄 책도 사서 타원형 체반이나 꽃컵받침도 만들고 하네요 ㅎㅎ',
              '첨엔 어떻게 하지..? 했는데 하다 보니까 너무 재밌어요~~ㅎㅎ 요새 더워서 짜증 폭발했었는데 좋은 클래스 들으면서 힐링~~',
              '여기왜이이래요? 앱도 없고 키트준비도안하고 강의신청 받고 cs도 답답하고 ... 이것도 후기니까 지우지 마세요',
              '강의는 어려운것보다도 일단 너무 많이 섞는것이 아닌 내가 선호하는 향위주로 만드는법을 알려주셨음 좋았을텐데 강의대로 했는데 그향이 그향인듯해요 다 비슷비슷',
              '처음으로 알게된 하바리움이었는데 수업검색을 하다 저의 눈길을 끌어. 듣게되었습니다. 취미생활로 저의 마음까지 안정하게만들어주네요. 너무 좋습니다.신비로워요',
              '엔님의 강의가 좋은 건 초보자도 쉽고 간단하게 천연비누를 만들 수 있다는 거예요! 덕분에 강의 듣고 실용성 있는 천연비누 완성했어요.']

# 위의 리뷰에 대한 감정
review_sentiment = ['good', 'sorry', 'good', 'sorry', 'good',
                    'good', 'good', 'good', 'good', 'sorry',
                   'sorry', 'good', 'sorry', 'sorry', 'good',
                   'good']

correct_cnt = 0
for i, review in enumerate(review_list):
    stemming_review = stemming(review)
    pos_score, neg_score, sentiment_percent, sentiment = return_sentiment(stemming_review, 48)
    if sentiment == review_sentiment[i]:
        correct_cnt += 1
    print(stemming_review)
    print('Positive Score: ', pos_score)
    print('Negative Score: ', neg_score)
    print('Sentiment Score: ', sentiment_percent)
    print('Sentiment: ', sentiment)
    print('실제 감성: {}'.format(review_sentiment[i]))
    print('-------------------------------------\n')

model_accuracy = np.round(((correct_cnt/(i+1))*100), 2)
print('전체 데이터셋 개수: {}'.format((i+1)))
print('맞춘 리뷰 개수: {}'.format(correct_cnt))
print('train datset에 대한 정확도: {}%'.format(model_accuracy))
# Out:
# 정말너무 너무 만족스럽다취미에요 . 재미도 있다결과물도 진짜예쁘다마음에 들다 . 전혀 돈이 아깝다않다 !!!! 수국 무드등도 얼른만들다 보다 겠다 ♡
# Positive Score:  1
# Negative Score:  3
# Sentiment Score:  25.0
# Sentiment:  sorry
# 실제 감성: good
# -------------------------------------
#
# 갈색시 약병이 공지못보다 건지다 바뀌다 걸모르다 그냥 유리 병이 오다 ~ 갈색 병 선물로 드리다 하다 실망하다바뀌다 점을 미리 공지하다 사진도 교체하다 좋다기분좋다재료받다 구성품이 바뀌다 기분안좋다
# Positive Score:  3
# Negative Score:  4
# Sentiment Score:  42.86
# Sentiment:  sorry
# 실제 감성: sorry
# -------------------------------------
#
# 울적하다기분을 캔들로 힐링하다 ~~ 정말행복하다 뿌듯하다성취 감 뿜뿜!!! 적극적으로 추천하다 ^^
# Positive Score:  6
# Negative Score:  0
# Sentiment Score:  100.0
# Sentiment:  good
# 실제 감성: good
# -------------------------------------
#
# 저울이 먹통이여서 그다음 날 연락하고 재 출고해주다 하다 . 하지만저희동네는 cj가다 밤10시에온다는거~ 일단그점이 아쉽다주말끼다 꽤오래 기다리다 터라 일단 저울은 다이소서 사서하다 온도계는 좀아쉽다온도가 천천히 올라가다 올려놓다 기다리다 야하다 불편하다향료 양도 좀아쉽다왁스는 다만들고 여유되다 근데 향료가 여유롭다 않다 제가 만들다 왁스 타블렛을 실수로 엎어서 저는 향료모자라다 .. ㅜ그거빼다 만족이다저는 버블 캔들 몰드다 닦다 하다 왜매끄럽다안나오다 ㅜㅜ추가 향료 사서 더만들다 보다
# Positive Score:  3
# Negative Score:  21
# Sentiment Score:  12.5
# Sentiment:  sorry
# 실제 감성: sorry
# -------------------------------------
#
# 마지막까지 완성하다 ! 거울은 염색시키다 하다 !! 라 타다 충분하다물에 불다 더예쁘다만들어지다 같다! 만들다 너무 뿌듯하다 예쁘다네욤! 단순 반복이라 처음에 자다 해두다 끝 부분까지는 금방하다 같다~~
# Positive Score:  5
# Negative Score:  8
# Sentiment Score:  38.46
# Sentiment:  sorry
# 실제 감성: good
# -------------------------------------
#
# 프랑스 자수좋아하다채색 자수는 처음보다 바로지르다 넓다면적을 물감을 칠하다오다 진짜기발하다그래서 너무 재밌다그림이랑 자수두다 배우다 수있다뭔가 가성 비높다취미라고 하다 하다 암튼 재밌다하다 있다!
# Positive Score:  2
# Negative Score:  1
# Sentiment Score:  66.67
# Sentiment:  good
# 실제 감성: good
# -------------------------------------
#
# 정규 클래스 처음인데 가격도 무난하고 좋다3개월 치가이정도면 .. 키트는 벌써받다 이번꺼패키지가 풍 성하다 좋다ㅎㅎ다음에는 새롭다해보다
# Positive Score:  3
# Negative Score:  2
# Sentiment Score:  60.0
# Sentiment:  good
# 실제 감성: good
# -------------------------------------
#
# 라 타다 엄청 재미있다설명도 친절하다이제 제 스스로 더만 들것을 찾아보다
# Positive Score:  2
# Negative Score:  1
# Sentiment Score:  66.67
# Sentiment:  good
# 실제 감성: good
# -------------------------------------
#
# 체험 단 당첨으로 만들다 돼다 사정이 생기다 이제야다 만들다 글을 써다 ! 처음에는 손도 아프다익숙 치않다 어렵다, 하나씩만들다 갈다 때마다 손재주가 늘다 보이다 ! 강의에서도 이해하다 쉬다 자다 설명해주다 이해하다 쉽다, 강의를 다시보다 보다 필요하다때보다 가장크다 장점인거 같다. 라 탄도충분하다양을 넣다 만들다 싶다 또만들다 같다! 전혀 돈아깝다않다 클래스같다! 덕분에 취미 생활이 하나 더늘다 ~ 감사하다 ~
# Positive Score:  11
# Negative Score:  32
# Sentiment Score:  25.58
# Sentiment:  sorry
# 실제 감성: good
# -------------------------------------
#
# 살짝 살짝헷갈리다부분이 있다하지만재밌다만들다
# Positive Score:  0
# Negative Score:  8
# Sentiment Score:  0.0
# Sentiment:  sorry
# 실제 감성: sorry
# -------------------------------------
#
# 좋다취미를 얻다 ♡입문 과정으로 듣기좋다마무리하다 때 살짝헷갈리다감이 있다좀 더 클로즈업해주다 좋다것같다아직도 확실하다하다 건가 제 작품에 좀 미심 쩍은 감이 있다ㅠㅠ이 강 좌보고 서점에 가다 라 타다 책도 사서 타원형 체반이나 꽃컵 받침도 만들다 하다 ㅎㅎ
# Positive Score:  4
# Negative Score:  19
# Sentiment Score:  17.39
# Sentiment:  sorry
# 실제 감성: sorry
# -------------------------------------
#
# 첨엔 어떻다하다 ..? 하다 하다 보니까 너무 재밌다~~ ㅎㅎ요새덥다짜증 폭발하다 좋다클래스들다 힐링~~
# Positive Score:  3
# Negative Score:  0
# Sentiment Score:  100.0
# Sentiment:  good
# 실제 감성: good
# -------------------------------------
#
# 여기 왜이이래 요? 앱도 없다키트 준비 도안하고 강의 신청받다 cs도답답하다... 이것도 후기니까 지우다 말다
# Positive Score:  1
# Negative Score:  3
# Sentiment Score:  25.0
# Sentiment:  sorry
# 실제 감성: sorry
# -------------------------------------
#
# 강의는 어렵다일단너무 많이 섞다 아니다내가 선호하다 향 위주로 만들다 법을 알다 좋다강의대로 하다 그향이 그향인 듯해요 다 비슷비슷
# Positive Score:  4
# Negative Score:  25
# Sentiment Score:  13.79
# Sentiment:  sorry
# 실제 감성: sorry
# -------------------------------------
#
# 처음으로 알게 되다 하바 리움이다 수업 검색을 하다 저의 눈길을 끌다 . 듣다 되어다 . 취미 생활로 저의 마음까지 안정하다 들어주다 . 너무 좋다. 신비롭다
# Positive Score:  5
# Negative Score:  2
# Sentiment Score:  71.43
# Sentiment:  good
# 실제 감성: good
# -------------------------------------
#
# 엔님의 강의가 좋다건 초보자도 쉬다 간단하다천 연비누를 만들다 수있다거예요 ! 덕분에 강의듣다 실용성있다천연 비누 완성하다 .
# Positive Score:  7
# Negative Score:  2
# Sentiment Score:  77.78
# Sentiment:  good
# 실제 감성: good
# -------------------------------------
#
# 전체 데이터셋 개수: 16
# 맞춘 리뷰 개수: 13
# train datset에 대한 정확도: 81.25%

# %% [markdown]
# ## 파라미터 조정 과정
# #### 조정하는 파라미터 종류
#
# - sentiment_score: 감정점수. 임계값으로서 해당 값을 넘으면 긍정, 넘지 못하면 부정으로 분류
# - pos_weight_score: 긍정 가중치. 해당 단어가 문장에 존재하면 추가 점수를 부여
# - neg_weight_score: 부정 가중치. 해당 단어가 문자엥 존해마면 추가 점수를 부여

# %%
import numpy as np
import pandas as pd


def neg_counter(data, neg_weight_score):
    negative_n = 0
    neg_front_search = ['보이지', '아깝다', '충분하다않다', '더자세하다', '더좋다', '아쉽다',
                        '쓸데없다', '느리다', '빠르다', '면 좋다', '좋다것같다', '안되다',
                        '헤메다', ' 좋다듯하다', '부족하다', '더들어가다', '어렵다', '비싸', '빠르다것같다', '자주나가다', '그만',
                        '너무늦다', '부족하다', '부분', '당황', '안타깝다']

    neg_back_search = ['다만', '없다', '그런데', '충분하다않다', '조금 더', '근데', '쓸데없다', '솔직', '너무짧다']

    neg_binary_search = ['실망', '부족', '버거운', '것같다', '좋다것같다', '단점', '너무짧다', '어렵다',
                         '때문에', '보완', '섬세', '너무많다', '무리', '않다', '기다']

    # 실망 댓글에서 분류하기 위한 3가지 카테고리 => 영상 품질 실망, 컨텐츠 내용 실망, 재료 관련 실망 카테고리
    neg_video_accord = ['버퍼링', '화질', '속도', '빠르다', '짧다', '보이지않다', '놓치다', '오류', '어둡다', '어두워지다',
                        '안들리다', '보이지', '안보이', '영상', '진도', '뚝뚝', '버퍼링', '스킵', '모양', '안들리다', '세밀',
                        '사이트', '과정', '하단', '확대', '보기', '감기', '초점', '안보이', '화질', '목소리', '평가',
                        '어두워지다', '클로즈업', '안보', '가까이', '화면', '모션', '자막', '오류', '각도']

    neg_content_accord = ['힘들다', '어렵다', '구체적', '헷갈', '반복되다', '환기', '진행', '해소가', '뒤죽박죽',
                          '안나오다', '각인', '장식', '단어', '돈', '작품', '답', '답장', '설명', '방법', '듣기', '교재', '이해', '비용', '힘들다',
                          '어렵다', '깊이', '용이', '초보자', '피드백', '수업', '빠르다', '속도', '시간', '내용', '만들기', '답변', '정보', '진행',
                          '기법', '너무짧다', '강의', '반복되다', '예시', '처음', '앞']

    neg_material_accord = ['촌스럽다', '얇다', '상품', '안오다', '구슬', '준비물', '분량',
                           '패키지', '안오다', '제품', '구성', '주문', '재료', '프린터']

    neg_weight_word = ['다만', '그런데', '충분하다않다', '조금 더', '근데', '쓸데없다', '어렵다', '안타깝다', '좋다것같다',
                       '아쉽다', '더필요하다', '조금불편하다']

    neg_word_list_zip = [neg_front_search, neg_back_search, neg_binary_search,
                         neg_video_accord, neg_content_accord, neg_material_accord]

    for neg_word_list in neg_word_list_zip:
        for neg_word in neg_word_list:
            if neg_word in data:
                if neg_word in neg_weight_word:
                    negative_n += neg_weight_score
                else:
                    negative_n += 1

    return negative_n


def pos_counter(data, pos_weight_score):
    positive_n = 0
    pos_front_search = ['빠르다', '감사', '알차다', '만족도', '성취감', '따르다', '구체적으로', '쉬다', '아주',
                        '자세하다', '알게', '좋다', '배우다', '꼼꼼하다', '쉽다', '피드백을', '가르치다', '따르다',
                        '뿌듯', '좋다']

    pos_back_search = ['빠르다', '감사', '알차다', '만족도', '성취감', '따르다', '구체적으로', '쉬다', '아주',
                       '자세하다', '알게', '좋다', '배우다', '꼼꼼하다', '쉽다', '피드백을', '가르치다', '따르다', '최고']

    # 긍정 댓글에서 분류하기 위한 2가지 카테고리 => 영상 설명, 결과물 만족 2가지 카테고리

    pos_content_accord = ['댓글', '답변', '친절', '정보', '팁', '성취', '설명', '피드백', '꼼꼼', '차분', '자세히', '차근차근',
                          '디테일', '기법', '상세', '강의', '이해', '자세', '쉽다', '다양', '실용', '알차다', '구체',
                          '노하우', '알차다']

    pos_product_accord = ['결과물', '디자인', '스타일', '퀄리티', '작품']

    pos_weight_word = ['최고', '너무 좋다', '뿌듯']

    pos_word_list_zip = [pos_front_search, pos_content_accord, pos_product_accord]
    for pos_word_list in pos_word_list_zip:
        for pos_word in pos_word_list:
            if pos_word in data:
                if pos_word in pos_weight_word:
                    positive_n += pos_weight_score
                else:
                    positive_n += 1

    return positive_n


def return_sentiment(data, sentiment_score, pos_weight_score, neg_weight_score):
    pos_score = pos_counter(data, pos_weight_score)
    neg_score = neg_counter(data, neg_weight_score)
    try:
        sentiment_percent = np.round((pos_score / (neg_score + pos_score)) * 100, 2)
    except:
        return 0, 0, 0, 'not enough data'

    if sentiment_percent > sentiment_score:
        return pos_score, neg_score, sentiment_percent, 'good'
    else:
        return pos_score, neg_score, sentiment_percent, 'sorry'


pos_reviewList = pd.read_excel('./dataset/stemming_good_review(row_2774).xlsx', engine='openpyxl')
pos_reviewList.drop(reviewList.loc[reviewList.review.isna()].index, axis=0, inplace=True)
pos_reviewList.reset_index(inplace=True)
pos_reviewList.drop('index', axis=1, inplace=True)

neg_reviewList = pd.read_excel('./dataset/stemming_sorry_review.xlsx', engine='openpyxl')
neg_reviewList.drop(reviewList.loc[reviewList.review.isna()].index, axis=0, inplace=True)
neg_reviewList.reset_index(inplace=True)
neg_reviewList.drop('index', axis=1, inplace=True)

data_n = 0
correct_n = 0
fail_n = 0
not_correct_n = 0

score_list = np.arange(40, 50)
pos_score_list = np.arange(2, 7)
neg_score_list = np.arange(2, 7)


score_param = []
pos_param_weight = []
neg_param_weight = []


pos_accuracy = []
neg_accuracy = []


case_cnt = 0
for score in score_list:
    for pos_weight in pos_score_list:
        for neg_weight in neg_score_list:
            for i in range(len(pos_reviewList)):
                review = pos_reviewList.iloc[i, 1]
                pos_score, neg_score, sent_per, sentiment = return_sentiment(review, score, pos_weight, neg_weight)
                data_n += 1
                if sentiment == 'good':
                    correct_n += 1

                elif sentiment == 'not enough data':
                    not_correct_n += 1
                    continue
                else:
                    fail_n += 1
            score_param.append(score)
            pos_param_weight.append(pos_weight)
            neg_param_weight.append(neg_weight)
            pos_accuracy.append(np.round(100 * correct_n / (correct_n + fail_n)))
            print('\n----------------------------긍부정 파라미터 조정 Case {}-------------------------------------'.format(case_cnt))
            case_cnt += 1
            print('sentiment_score(임계값): {}\npos_weight_score: {}\nneg_weight_score: {}\n'.format(score, pos_weight, neg_weight))
            print('긍정분류 정확도: {}%'.format(np.round(100 * correct_n / (correct_n + fail_n))))
            data_n = 0
            correct_n = 0
            fail_n = 0
            not_correct_n = 0
            
            
                    
            for i in range(len(neg_reviewList)):
                review = neg_reviewList.iloc[i, 1]
                pos_score, neg_score, sent_per, sentiment = return_sentiment(review, score, pos_weight, neg_weight)
                data_n += 1
                if sentiment == 'sorry':
                    correct_n += 1


                elif sentiment == 'not enough data':
                    not_correct_n += 1
                    continue
                else:
                    fail_n += 1
            neg_accuracy.append(np.round(100 * correct_n / (correct_n + fail_n)))

            print('부정분류 정확도: {}%'.format(np.round(100 * correct_n / (correct_n + fail_n))))
            data_n = 0
            correct_n = 0
            fail_n = 0
            not_correct_n = 0
# Out:
# ----------------------------긍부정 파라미터 조정 Case 0-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 1-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 2-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 3-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 4-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 5-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 6-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 7-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 8-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 9-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 10-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 11-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 12-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 13-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 14-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 15-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 16-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 17-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 18-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 19-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 20-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 21-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 22-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 23-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 24-------------------------------------
# sentiment_score(임계값): 40
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 25-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 26-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 27-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 28-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 29-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 30-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 31-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 32-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 33-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 34-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 35-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 36-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 37-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 38-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 39-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 40-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 41-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 42-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 43-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 44-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
# ----------------------------긍부정 파라미터 조정 Case 45-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 81.0%
# 부정분류 정확도: 72.0%
#
# ----------------------------긍부정 파라미터 조정 Case 46-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 75.0%
#
# ----------------------------긍부정 파라미터 조정 Case 47-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 48-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 81.0%
#
# ----------------------------긍부정 파라미터 조정 Case 49-------------------------------------
# sentiment_score(임계값): 41
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 50-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 74.0%
#
# ----------------------------긍부정 파라미터 조정 Case 51-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 52-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 53-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 54-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 55-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 74.0%
#
# ----------------------------긍부정 파라미터 조정 Case 56-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 57-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 58-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 59-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 60-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 74.0%
#
# ----------------------------긍부정 파라미터 조정 Case 61-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 62-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 63-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 64-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 65-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 74.0%
#
# ----------------------------긍부정 파라미터 조정 Case 66-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 67-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 68-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 69-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 70-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 80.0%
# 부정분류 정확도: 74.0%
#
# ----------------------------긍부정 파라미터 조정 Case 71-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 72-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 73-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 74-------------------------------------
# sentiment_score(임계값): 42
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 75-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 76-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 77-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 78-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 79-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 80-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 81-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 82-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 83-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 84-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 85-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 86-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 87-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 88-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 89-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 90-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
# ----------------------------긍부정 파라미터 조정 Case 91-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 92-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 93-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 94-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 95-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 96-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 97-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 98-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 99-------------------------------------
# sentiment_score(임계값): 43
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 100-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 101-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 102-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 103-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 104-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 105-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 106-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 107-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 108-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 109-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 110-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 111-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 112-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 113-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 114-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 115-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 116-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 117-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 118-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 119-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 120-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 79.0%
# 부정분류 정확도: 76.0%
#
# ----------------------------긍부정 파라미터 조정 Case 121-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 122-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 123-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 124-------------------------------------
# sentiment_score(임계값): 44
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 125-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 126-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 80.0%
#
# ----------------------------긍부정 파라미터 조정 Case 127-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 128-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 129-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 130-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 131-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 80.0%
#
# ----------------------------긍부정 파라미터 조정 Case 132-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 133-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 134-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 135-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 136-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
# ----------------------------긍부정 파라미터 조정 Case 137-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 138-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 139-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 140-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 141-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 142-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 143-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 144-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 145-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 146-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 147-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 148-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 149-------------------------------------
# sentiment_score(임계값): 45
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 150-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 151-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 152-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 153-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 154-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 155-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 156-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 157-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 158-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 159-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 160-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 161-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 162-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 163-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 164-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 165-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 166-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 167-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 168-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 169-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 170-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 77.0%
#
# ----------------------------긍부정 파라미터 조정 Case 171-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 82.0%
#
# ----------------------------긍부정 파라미터 조정 Case 172-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 173-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 174-------------------------------------
# sentiment_score(임계값): 46
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 175-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 176-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 177-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 178-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 179-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 180-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 181-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
# ----------------------------긍부정 파라미터 조정 Case 182-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 183-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 184-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 185-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 186-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 187-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 188-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 189-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 190-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 191-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 192-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 193-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 194-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 195-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 78.0%
#
# ----------------------------긍부정 파라미터 조정 Case 196-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 197-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 85.0%
#
# ----------------------------긍부정 파라미터 조정 Case 198-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 199-------------------------------------
# sentiment_score(임계값): 47
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 200-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 201-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 202-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 203-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 204-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 89.0%
#
# ----------------------------긍부정 파라미터 조정 Case 205-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 206-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 207-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 208-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 209-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 89.0%
#
# ----------------------------긍부정 파라미터 조정 Case 210-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 211-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 212-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 213-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 214-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 89.0%
#
# ----------------------------긍부정 파라미터 조정 Case 215-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 216-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 217-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 218-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 219-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 220-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 221-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 222-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 223-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 224-------------------------------------
# sentiment_score(임계값): 48
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 225-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 2
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 226-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 2
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
# ----------------------------긍부정 파라미터 조정 Case 227-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 2
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 228-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 2
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 229-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 2
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 89.0%
#
# ----------------------------긍부정 파라미터 조정 Case 230-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 3
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 231-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 3
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 232-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 3
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 233-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 3
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 234-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 3
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 89.0%
#
# ----------------------------긍부정 파라미터 조정 Case 235-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 4
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 236-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 4
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 84.0%
#
# ----------------------------긍부정 파라미터 조정 Case 237-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 4
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 238-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 4
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 239-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 4
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 89.0%
#
# ----------------------------긍부정 파라미터 조정 Case 240-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 5
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 241-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 5
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 242-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 5
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 243-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 5
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 244-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 5
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%
#
# ----------------------------긍부정 파라미터 조정 Case 245-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 6
# neg_weight_score: 2
#
# 긍정분류 정확도: 78.0%
# 부정분류 정확도: 79.0%
#
# ----------------------------긍부정 파라미터 조정 Case 246-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 6
# neg_weight_score: 3
#
# 긍정분류 정확도: 77.0%
# 부정분류 정확도: 83.0%
#
# ----------------------------긍부정 파라미터 조정 Case 247-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 6
# neg_weight_score: 4
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 86.0%
#
# ----------------------------긍부정 파라미터 조정 Case 248-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 6
# neg_weight_score: 5
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 87.0%
#
# ----------------------------긍부정 파라미터 조정 Case 249-------------------------------------
# sentiment_score(임계값): 49
# pos_weight_score: 6
# neg_weight_score: 6
#
# 긍정분류 정확도: 76.0%
# 부정분류 정확도: 88.0%

# %%
max_accuracy = pos_accuracy[0] + neg_accuracy[0]
min_deviation = np.abs(pos_accuracy[0] - neg_accuracy[0])
max_index = 0

for i in range(len(score_param)):
    accuracy = pos_accuracy[i] + neg_accuracy[i]
    deviation = np.abs(pos_accuracy[i] - neg_accuracy[i])
    
    if max_accuracy < accuracy:
        if min_deviation >= deviation:
            max_accuracy = accuracy
            min_deviation = deviation
            max_index = i
            
print('인덱스: ', max_index)
print('감정점수 임계값: ', score_param[max_index])
print('긍정 정확도: ', pos_accuracy[max_index])
print('부정 정확도: ', neg_accuracy[max_index])
print('----------------------------------')
print('최종 정확도 합산: ', max_accuracy)
print('최종 편차: ', min_deviation)
print('최종 긍정 가중치: ', pos_param_weight[max_index])
print('최종 부정 가중치: ', neg_param_weight[max_index])
# Out:
# 인덱스:  13
# 감정점수 임계값:  40
# 긍정 정확도:  79.0
# 부정 정확도:  81.0
# ----------------------------------
# 최종 정확도 합산:  160.0
# 최종 편차:  2.0
# 최종 긍정 가중치:  4
# 최종 부정 가중치:  5

# %%
review = '기분을 캔들로 힐링하다 정말 행복하다 뿌듯하다 성취감 적극적으로 추천하다'
pos_score, neg_score, sent_per, sentiment =  return_sentiment(review, 40, 4, 5)
print(pos_score, neg_score, sent_per, sentiment)
# Out:
# 6 0 100.0 good
